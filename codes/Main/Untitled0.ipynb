# %% [markdown]
# # 00 Init

# %% [markdown]
# ## Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Setting to use py files

# %%
import os

# %%
os.chdir('/content/drive/MyDrive/Minesweeper [RL]')

# %%
# check that os is in right directory
os.getcwd()
# Out:
# '/content/drive/MyDrive/Minesweeper [RL]'

# %%
! pip install codes
# Out:
# Collecting codes
#   Downloading codes-0.1.5-py3-none-any.whl (5.5 kB)
# Installing collected packages: codes
# Successfully installed codes-0.1.5

# %% [markdown]
# ## Import py files

# %%
# baseline : Env, Agent
# from codes.environment.reward5 import *
from codes.environment.reward5 import *
from codes.agent.vectorDQN import *
from codes.net.basic import *
from codes.trainer.validShutDown import *
# import codes.trainer.trainerWithValidShutDown as Trainer

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# # 01 Info

# %% [markdown]
# ## level dictionary

# %%
level = {'easy' : {'map_size':(9,9), 'n_mines' : 10},
         'medium' : {'map_size':(16,16), 'n_mines':40},
         'expert' : {'map_size':(16,30), 'n_mines':99}}

# %% [markdown]
# ## HYPER PARAMETERS

# %%
# Environment settings
MEM_SIZE = 50000
MEM_SIZE_MIN = 1000

# Learning settings
BATCH_SIZE = 64
LEARNING_RATE = 0.01
LEARN_DECAY = 0.99975
LEARN_MIN = 0.001
DISCOUNT = 0.1

# Exploration settings
EPSILON = 0.95
EPSILON_DECAY = 0.99975
EPSILON_MIN = 0.01

# DQN settings
CONV_UNITS = 64
UPDATE_TARGET_EVERY = 5

# %% [markdown]
# # 02 Train, Valid

# %%
env = MinesweeperEnv(map_size=level['easy']['map_size'],
                     n_mines=level['easy']['n_mines'])

net = Net(input_dims=env.state.shape,
          n_actions=env.total_tiles,
          conv_units=CONV_UNITS)

agent = Limited18Agent(env=env,
                        net=net,
                        MEM_SIZE=MEM_SIZE,
                        MEM_SIZE_MIN=MEM_SIZE_MIN,
                        BATCH_SIZE=BATCH_SIZE,
                        LEARNING_RATE=LEARNING_RATE,
                        LEARN_DECAY=LEARN_DECAY,
                        LEARN_MIN=LEARN_MIN,
                        DISCOUNT=DISCOUNT,
                        EPSILON=EPSILON,
                        EPSILON_DECAY=EPSILON_DECAY,
                        EPSILON_MIN=EPSILON_MIN,
                        UPDATE_TARGET_EVERY=UPDATE_TARGET_EVERY)

# %% [markdown]
# ## TRAIN_PARAMETERS

# %%
EPISODES = 200000
PRINT_INTERVAL = 100
TRAIN_RENDER = False

TRAIN_TIMESTEPS = ['every timestep', 'every episodes']
TRAIN_TIMESTEP = TRAIN_TIMESTEPS[0]
VIUSAL_INTERVAL = 100

VALID_SAMPLE = 1000
VALID_INTERVAL = 10

# %%
tester_agent = Agent(env=env,
                    net=net,
                    MEM_SIZE=MEM_SIZE,
                    MEM_SIZE_MIN=MEM_SIZE_MIN,
                    BATCH_SIZE=BATCH_SIZE,
                    LEARNING_RATE=LEARNING_RATE,
                    LEARN_DECAY=LEARN_DECAY,
                    LEARN_MIN=LEARN_MIN,
                    DISCOUNT=DISCOUNT,
                    EPSILON=EPSILON,
                    EPSILON_DECAY=EPSILON_DECAY,
                    EPSILON_MIN=EPSILON_MIN,
                    UPDATE_TARGET_EVERY=UPDATE_TARGET_EVERY)

# %%
trainer = Trainer(env=env,
                    agent=agent,
                    tester_agent=tester_agent,
                    name='episodeInterval',
                    train_start=True,
                    EPISODES = EPISODES,
                    PRINT_INTERVAL = PRINT_INTERVAL,
                    TRAIN_RENDER = TRAIN_RENDER,
                    TRAIN_TIMESTEP = TRAIN_TIMESTEPS[0],
                    VIUSAL_INTERVAL = VIUSAL_INTERVAL,
                    VALID_SAMPLE = VALID_SAMPLE,
                    VALID_INTERVAL = VALID_INTERVAL)
# Out:
# Episode: [200000/100], Median progress: 7.00, Median reward: -2.20, Win rate : 0.00, Epsilon: 0.95
# Episode: [200000/200], Median progress: 7.00, Median reward: -2.20, Win rate : 0.00, Epsilon: 0.86
# Episode: [200000/300], Median progress: 6.00, Median reward: -1.90, Win rate : 0.00, Epsilon: 0.69
# Episode: [200000/400], Median progress: 7.50, Median reward: -2.20, Win rate : 0.00, Epsilon: 0.55
# Episode: [200000/500], Median progress: 7.00, Median reward: -2.20, Win rate : 0.00, Epsilon: 0.42
# Episode: [200000/600], Median progress: 6.00, Median reward: -2.20, Win rate : 0.00, Epsilon: 0.32
# Episode: [200000/700], Median progress: 10.00, Median reward: -2.95, Win rate : 0.00, Epsilon: 0.22
# Episode: [200000/800], Median progress: 9.50, Median reward: -2.50, Win rate : 0.00, Epsilon: 0.11
# Episode: [200000/900], Median progress: 6.00, Median reward: -1.90, Win rate : 0.00, Epsilon: 0.05
# Episode: [200000/1000], Median progress: 6.50, Median reward: -2.20, Win rate : 0.00, Epsilon: 0.02
# Episode: [200000/1100], Median progress: 15.50, Median reward: -5.05, Win rate : 0.00, Epsilon: 0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-620c0ce84850> in <cell line: 1>()
# ----> 1 trainer = Trainer(env=env,
#       2                     agent=agent,
#       3                     tester_agent=tester_agent,
#       4                     name='episodeInterval',
#       5                     train_start=True,
#
# /content/drive/MyDrive/Minesweeper [RL]/codes/trainer/validShutDown.py in __init__(self, env, agent, tester_agent, name, train_start, **kwargs)
#      53
#      54         if train_start:
# ---> 55             self.train()
#      56             self.visualize_train()
#      57             self.save_model()
#
# /content/drive/MyDrive/Minesweeper [RL]/codes/trainer/validShutDown.py in train(self)
#      83
#      84                 if self.train_timestep == TRAIN_TIMESTEPS[0]: # every timestep
# ---> 85                     self.agent.train(done)
#      86
#      87                 n_clicks += 1
#
# <ipython-input-17-781c3a04fffa> in train(self, done)
#     113         cost = self.loss_fn(y_est, y)
#     114
# --> 115         running_loss = cost.item()
#     116         self.losses.append(round(running_loss,6))
#     117
#
# KeyboardInterrupt:

# %% [markdown]
# # 01
