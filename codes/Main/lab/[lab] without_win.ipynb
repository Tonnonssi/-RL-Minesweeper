# %%
FNAME = 'without_win'

# %% [markdown]
# # 00 Init

# %% [markdown]
# ## Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Setting to use py files

# %%
import os

# %%
os.chdir('/content/drive/MyDrive/Minesweeper [RL]')

# %%
# check that os is in right directory
os.getcwd()
# Out:
# '/content/drive/MyDrive/Minesweeper [RL]'

# %%
! pip install codes
# Out:
# Collecting codes
#   Downloading codes-0.1.5-py3-none-any.whl (5.5 kB)
# Installing collected packages: codes
# Successfully installed codes-0.1.5

# %% [markdown]
# ## Import py files

# %%
# baseline : Env, Agent
# from codes.environment.reward5 import *
from codes.environment.reward5 import *
from codes.agent.newVectorDQN import *
from codes.net.basicWithBias import *
from codes.trainer.validShutDown import *
# from codes.tester.basic import *
from codes.tester.validShutDown import *
# import codes.trainer.trainerWithValidShutDown as Trainer

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# # 01 Info

# %% [markdown]
# ## level dictionary

# %%
level = {'easy' : {'map_size':(9,9), 'n_mines' : 10},
         'medium' : {'map_size':(16,16), 'n_mines':40},
         'expert' : {'map_size':(16,30), 'n_mines':99}}

# %% [markdown]
# ## HYPER PARAMETERS

# %%
# Environment settings
MEM_SIZE = 50000
MEM_SIZE_MIN = 1000

# Learning settings
BATCH_SIZE = 64
LEARNING_RATE = 0.001
LEARN_DECAY = 0.25
LEARN_EPOCH = 50000
# LEARN_MIN = 0.001
DISCOUNT = 0.1

# Exploration settings
EPSILON = 0.95
EPSILON_DECAY = 0.999975
EPSILON_MIN = 0.01

# DQN settings
CONV_UNITS = 128
UPDATE_TARGET_EVERY = 5

# %% [markdown]
# # 02 Train, Valid

# %%
env = MinesweeperEnv(map_size=level['easy']['map_size'],
                     n_mines=level['easy']['n_mines'],
                     rewards={'win':1, 'lose':-1, 'progress':1, 'guess':0.5, 'no_progress' : -1},
                    dones={'win':True, 'lose':True, 'progress':False, 'guess':False, 'no_progress' : False})

net = Net(input_dims=env.state.shape,
          n_actions=env.total_tiles,
          conv_units=CONV_UNITS)

agent = Agent(env=env,
              net=net,
              MEM_SIZE=MEM_SIZE,
              MEM_SIZE_MIN=MEM_SIZE_MIN,
              BATCH_SIZE=BATCH_SIZE,
              LEARNING_RATE=LEARNING_RATE,
              LEARN_DECAY=LEARN_DECAY,
              LEARN_EPOCH=LEARN_EPOCH,
              # LEARN_MIN=LEARN_MIN,
              DISCOUNT=DISCOUNT,
              EPSILON=EPSILON,
              EPSILON_DECAY=EPSILON_DECAY,
              EPSILON_MIN=EPSILON_MIN,
              UPDATE_TARGET_EVERY=UPDATE_TARGET_EVERY)

# %% [markdown]
# ## TRAIN_PARAMETERS

# %%
EPISODES = 100000
PRINT_INTERVAL = 100
TRAIN_RENDER = False

TRAIN_TIMESTEPS = ['every timestep', 'every episodes']
TRAIN_TIMESTEP = TRAIN_TIMESTEPS[0]
VIUSAL_INTERVAL = 100

VALID_SAMPLE = 1000
VALID_INTERVAL = 10

# %% [markdown]
# ## valid agent in train

# %%
tester_agent = Agent(env=env,
                    net=net,
                    MEM_SIZE=MEM_SIZE,
                    MEM_SIZE_MIN=MEM_SIZE_MIN,
                    BATCH_SIZE=BATCH_SIZE,
                    LEARNING_RATE=LEARNING_RATE,
                    LEARN_DECAY=LEARN_DECAY,
                    # LEARN_MIN=LEARN_MIN,
                    LEARN_EPOCH=LEARN_EPOCH,
                    DISCOUNT=DISCOUNT,
                    EPSILON=EPSILON,
                    EPSILON_DECAY=EPSILON_DECAY,
                    EPSILON_MIN=EPSILON_MIN,
                    UPDATE_TARGET_EVERY=UPDATE_TARGET_EVERY)

# %% [markdown]
# ## main

# %%
trainer = Trainer(env=env,
                    agent=agent,
                    tester_agent=tester_agent,
                    name=FNAME,
                    train_start=False,
                    EPISODES = EPISODES,
                    PRINT_INTERVAL = PRINT_INTERVAL,
                    TRAIN_RENDER = TRAIN_RENDER,
                    TRAIN_TIMESTEP = TRAIN_TIMESTEP,
                    VIUSAL_INTERVAL = VIUSAL_INTERVAL,
                    VALID_SAMPLE = VALID_SAMPLE,
                    VALID_INTERVAL = VALID_INTERVAL)

# %%
with open(os.path.join(trainer.total_path, f'{2*EPISODES}'), "rb") as f:
    trainer = pickle.load(f)

# %%
trainer = Trainer(env=env,
                    agent=agent,
                    tester_agent=tester_agent,
                    name=FNAME,
                    train_start=True,
                    EPISODES = EPISODES,
                    PRINT_INTERVAL = PRINT_INTERVAL,
                    TRAIN_RENDER = TRAIN_RENDER,
                    TRAIN_TIMESTEP = TRAIN_TIMESTEP,
                    VIUSAL_INTERVAL = VIUSAL_INTERVAL,
                    VALID_SAMPLE = VALID_SAMPLE,
                    VALID_INTERVAL = VALID_INTERVAL)
# Out:
# Episode: [100000/100]| Median progress: 8.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.95
# Episode: [100000/200]| Median progress: 6.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.93
# Episode: [100000/300]| Median progress: 7.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.91
# Episode: [100000/400]| Median progress: 8.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.89
# Episode: [100000/500]| Median progress: 6.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.87
# Episode: [100000/600]| Median progress: 7.00 | Median reward: -0.25 | Win rate : 0.000 | Epsilon: 0.86
# Episode: [100000/700]| Median progress: 6.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.84
# Episode: [100000/800]| Median progress: 8.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.82
# Episode: [100000/900]| Median progress: 6.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.81
# Episode: [100000/1000]| Median progress: 8.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.79
# Episode: [100000/1100]| Median progress: 6.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.77
# Episode: [100000/1200]| Median progress: 7.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.75
# Episode: [100000/1300]| Median progress: 7.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.74
# Episode: [100000/1400]| Median progress: 8.50 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.72
# Episode: [100000/1500]| Median progress: 6.00 | Median reward: 0.00 | Win rate : 0.000 | Epsilon: 0.70
# Episode: [100000/1600]| Median progress: 5.00 | Median reward: 0.00 | Win rate : 0.000 | Epsilon: 0.69
# Episode: [100000/1700]| Median progress: 6.00 | Median reward: 0.00 | Win rate : 0.000 | Epsilon: 0.67
# Episode: [100000/1800]| Median progress: 5.50 | Median reward: -0.50 | Win rate : 0.010 | Epsilon: 0.66
# valid latest successed model
# Valid n:1000, Median progress: 6.00, Median reward: 2.50, Win rate : 0.001
# Valid n:1000, Median progress: 6.00, Median reward: 2.50, Win rate : 0.001
# Valid n:1000, Median progress: 6.00, Median reward: 2.00, Win rate : 0.0
# Valid n:1000, Median progress: 6.00, Median reward: 2.00, Win rate : 0.0
# Valid n:1000, Median progress: 6.00, Median reward: 2.00, Win rate : 0.0
# Valid n:1000, Median progress: 5.00, Median reward: 2.00, Win rate : 0.0
# Valid n:1000, Median progress: 5.00, Median reward: 2.00, Win rate : 0.001
# Valid n:1000, Median progress: 5.00, Median reward: 2.00, Win rate : 0.0
# Valid n:1000, Median progress: 6.00, Median reward: 2.00, Win rate : 0.001
# Valid n:1000, Median progress: 6.00, Median reward: 2.00, Win rate : 0.0
# Valid n:1000, Median progress: 5.00, Median reward: 1.50, Win rate : 0.0
# Episode: [100000/1900]| Median progress: 6.00 | Median reward: 0.00 | Win rate : 0.000 | Epsilon: 0.65
# Episode: [100000/2000]| Median progress: 8.00 | Median reward: 0.00 | Win rate : 0.000 | Epsilon: 0.63
# Episode: [100000/2100]| Median progress: 6.50 | Median reward: 0.00 | Win rate : 0.000 | Epsilon: 0.62
# Episode: [100000/2200]| Median progress: 5.00 | Median reward: -0.50 | Win rate : 0.000 | Epsilon: 0.61
# Episode: [100000/2300]| Median progress: 6.00 | Median reward: 0.00 | Win rate : 0.000 | Epsilon: 0.59
# Episode: [100000/2400]| Median progress: 8.00 | Median reward: 0.50 | Win rate : 0.000 | Epsilon: 0.58
# Episode: [100000/2500]| Median progress: 6.00 | Median reward: 0.50 | Win rate : 0.000 | Epsilon: 0.57
# Episode: [100000/2600]| Median progress: 8.50 | Median reward: 0.50 | Win rate : 0.000 | Epsilon: 0.55
# Episode: [100000/2700]| Median progress: 6.00 | Median reward: 0.50 | Win rate : 0.000 | Epsilon: 0.54
# Episode: [100000/2800]| Median progress: 7.00 | Median reward: 0.00 | Win rate : 0.000 | Epsilon: 0.53
# Episode: [100000/2900]| Median progress: 7.00 | Median reward: 0.00 | Win rate : 0.000 | Epsilon: 0.52
# Episode: [100000/3000]| Median progress: 6.00 | Median reward: 0.50 | Win rate : 0.000 | Epsilon: 0.51
# Episode: [100000/3100]| Median progress: 5.50 | Median reward: 0.00 | Win rate : 0.000 | Epsilon: 0.49
# Episode: [100000/3200]| Median progress: 5.00 | Median reward: 0.50 | Win rate : 0.000 | Epsilon: 0.49
# Episode: [100000/3300]| Median progress: 6.00 | Median reward: 0.00 | Win rate : 0.000 | Epsilon: 0.48
# Episode: [100000/3400]| Median progress: 6.00 | Median reward: 0.50 | Win rate : 0.000 | Epsilon: 0.47
# Episode: [100000/3500]| Median progress: 6.50 | Median reward: 0.50 | Win rate : 0.000 | Epsilon: 0.46
# Episode: [100000/3600]| Median progress: 7.00 | Median reward: 1.50 | Win rate : 0.000 | Epsilon: 0.45
# Episode: [100000/3700]| Median progress: 7.00 | Median reward: 0.50 | Win rate : 0.020 | Epsilon: 0.44
# valid latest successed model
# Valid n:1000, Median progress: 6.00, Median reward: 2.50, Win rate : 0.001
# Valid n:1000, Median progress: 6.00, Median reward: 2.50, Win rate : 0.003
# Valid n:1000, Median progress: 6.00, Median reward: 3.00, Win rate : 0.0
# Valid n:1000, Median progress: 6.00, Median reward: 2.50, Win rate : 0.0
# Valid n:1000, Median progress: 6.00, Median reward: 3.00, Win rate : 0.002
# Valid n:1000, Median progress: 6.00, Median reward: 2.50, Win rate : 0.003
# Valid n:1000, Median progress: 6.00, Median reward: 2.50, Win rate : 0.002
# Valid n:1000, Median progress: 6.00, Median reward: 2.50, Win rate : 0.001
# Valid n:1000, Median progress: 6.00, Median reward: 3.00, Win rate : 0.0
# Valid n:1000, Median progress: 6.00, Median reward: 2.50, Win rate : 0.001
# Valid n:1000, Median progress: 6.00, Median reward: 2.50, Win rate : 0.0
# Episode: [100000/3800]| Median progress: 7.00 | Median reward: 1.00 | Win rate : 0.000 | Epsilon: 0.43
# Episode: [100000/3900]| Median progress: 8.00 | Median reward: 0.50 | Win rate : 0.010 | Epsilon: 0.42
# Episode: [100000/4000]| Median progress: 8.00 | Median reward: 1.00 | Win rate : 0.000 | Epsilon: 0.40
# Episode: [100000/4100]| Median progress: 7.00 | Median reward: 1.00 | Win rate : 0.000 | Epsilon: 0.40
# Episode: [100000/4200]| Median progress: 7.00 | Median reward: 0.75 | Win rate : 0.010 | Epsilon: 0.39
# Episode: [100000/4300]| Median progress: 6.00 | Median reward: 1.00 | Win rate : 0.000 | Epsilon: 0.38
# Episode: [100000/4400]| Median progress: 7.00 | Median reward: 1.50 | Win rate : 0.000 | Epsilon: 0.37
# Episode: [100000/4500]| Median progress: 6.00 | Median reward: 1.00 | Win rate : 0.010 | Epsilon: 0.36
# Episode: [100000/4600]| Median progress: 6.00 | Median reward: 0.50 | Win rate : 0.000 | Epsilon: 0.35
# Episode: [100000/4700]| Median progress: 7.00 | Median reward: 1.50 | Win rate : 0.000 | Epsilon: 0.35
# Episode: [100000/4800]| Median progress: 6.00 | Median reward: 1.00 | Win rate : 0.000 | Epsilon: 0.34
# Episode: [100000/4900]| Median progress: 6.00 | Median reward: 1.00 | Win rate : 0.010 | Epsilon: 0.33
# Episode: [100000/5000]| Median progress: 6.50 | Median reward: 1.00 | Win rate : 0.010 | Epsilon: 0.32
# Episode: [100000/5100]| Median progress: 6.50 | Median reward: 2.00 | Win rate : 0.010 | Epsilon: 0.32
# Episode: [100000/5200]| Median progress: 7.00 | Median reward: 1.00 | Win rate : 0.000 | Epsilon: 0.31
# Episode: [100000/5300]| Median progress: 6.00 | Median reward: 0.75 | Win rate : 0.000 | Epsilon: 0.30
# Episode: [100000/5400]| Median progress: 7.00 | Median reward: 1.00 | Win rate : 0.010 | Epsilon: 0.30
# Episode: [100000/5500]| Median progress: 6.00 | Median reward: 1.50 | Win rate : 0.010 | Epsilon: 0.29
# Episode: [100000/5600]| Median progress: 6.50 | Median reward: 1.00 | Win rate : 0.000 | Epsilon: 0.28
# Episode: [100000/5700]| Median progress: 6.50 | Median reward: 1.50 | Win rate : 0.000 | Epsilon: 0.28
# Episode: [100000/5800]| Median progress: 7.00 | Median reward: 1.00 | Win rate : 0.010 | Epsilon: 0.27
# Episode: [100000/5900]| Median progress: 7.00 | Median reward: 1.50 | Win rate : 0.000 | Epsilon: 0.26
# Episode: [100000/6000]| Median progress: 6.50 | Median reward: 1.75 | Win rate : 0.000 | Epsilon: 0.25
# Episode: [100000/6100]| Median progress: 8.00 | Median reward: 1.50 | Win rate : 0.000 | Epsilon: 0.25
# Episode: [100000/6200]| Median progress: 7.50 | Median reward: 2.00 | Win rate : 0.000 | Epsilon: 0.24
# Episode: [100000/6300]| Median progress: 8.00 | Median reward: 1.50 | Win rate : 0.000 | Epsilon: 0.23
# Episode: [100000/6400]| Median progress: 7.00 | Median reward: 2.25 | Win rate : 0.000 | Epsilon: 0.23
# Episode: [100000/6500]| Median progress: 6.00 | Median reward: 1.75 | Win rate : 0.000 | Epsilon: 0.22
# Episode: [100000/6600]| Median progress: 7.00 | Median reward: 1.75 | Win rate : 0.020 | Epsilon: 0.22
# Episode: [100000/6700]| Median progress: 6.50 | Median reward: 1.25 | Win rate : 0.000 | Epsilon: 0.21
# Episode: [100000/6800]| Median progress: 7.00 | Median reward: 2.00 | Win rate : 0.000 | Epsilon: 0.20
# Episode: [100000/6900]| Median progress: 8.50 | Median reward: 1.25 | Win rate : 0.010 | Epsilon: 0.20
# Episode: [100000/7000]| Median progress: 7.50 | Median reward: 1.25 | Win rate : 0.010 | Epsilon: 0.19
# Episode: [100000/7100]| Median progress: 6.00 | Median reward: 1.25 | Win rate : 0.020 | Epsilon: 0.19
# Episode: [100000/7200]| Median progress: 7.00 | Median reward: 2.00 | Win rate : 0.010 | Epsilon: 0.18
# Episode: [100000/7300]| Median progress: 6.00 | Median reward: 2.00 | Win rate : 0.000 | Epsilon: 0.18
# Episode: [100000/7400]| Median progress: 6.50 | Median reward: 1.00 | Win rate : 0.010 | Epsilon: 0.17
# Episode: [100000/7500]| Median progress: 7.00 | Median reward: 2.50 | Win rate : 0.030 | Epsilon: 0.17
# valid latest successed model
# Valid n:1000, Median progress: 7.00, Median reward: 4.00, Win rate : 0.005
# Valid n:1000, Median progress: 7.00, Median reward: 4.00, Win rate : 0.007
# Valid n:1000, Median progress: 7.00, Median reward: 4.00, Win rate : 0.003
# Valid n:1000, Median progress: 6.00, Median reward: 3.50, Win rate : 0.004
# Valid n:1000, Median progress: 7.00, Median reward: 3.50, Win rate : 0.004
# Valid n:1000, Median progress: 7.00, Median reward: 3.50, Win rate : 0.005
# Valid n:1000, Median progress: 6.00, Median reward: 3.50, Win rate : 0.004
# Valid n:1000, Median progress: 7.00, Median reward: 3.50, Win rate : 0.003
# Valid n:1000, Median progress: 6.00, Median reward: 3.50, Win rate : 0.001
# Valid n:1000, Median progress: 7.00, Median reward: 3.50, Win rate : 0.004
# Valid n:1000, Median progress: 7.00, Median reward: 3.50, Win rate : 0.002
# Episode: [100000/7600]| Median progress: 6.00 | Median reward: 2.00 | Win rate : 0.000 | Epsilon: 0.16
# Episode: [100000/7700]| Median progress: 6.00 | Median reward: 1.50 | Win rate : 0.010 | Epsilon: 0.16
# Episode: [100000/7800]| Median progress: 7.00 | Median reward: 2.00 | Win rate : 0.010 | Epsilon: 0.16
# Episode: [100000/7900]| Median progress: 7.50 | Median reward: 2.50 | Win rate : 0.010 | Epsilon: 0.15
# Episode: [100000/8000]| Median progress: 7.00 | Median reward: 1.50 | Win rate : 0.010 | Epsilon: 0.14
# Episode: [100000/8100]| Median progress: 7.00 | Median reward: 1.75 | Win rate : 0.000 | Epsilon: 0.14
# Episode: [100000/8200]| Median progress: 7.50 | Median reward: 2.00 | Win rate : 0.000 | Epsilon: 0.14
# Episode: [100000/8300]| Median progress: 7.00 | Median reward: 2.50 | Win rate : 0.010 | Epsilon: 0.13
# Episode: [100000/8400]| Median progress: 8.00 | Median reward: 2.00 | Win rate : 0.000 | Epsilon: 0.13
# Episode: [100000/8500]| Median progress: 8.00 | Median reward: 2.50 | Win rate : 0.000 | Epsilon: 0.12
# Episode: [100000/8600]| Median progress: 7.00 | Median reward: 2.00 | Win rate : 0.010 | Epsilon: 0.12
# Episode: [100000/8700]| Median progress: 7.00 | Median reward: 3.00 | Win rate : 0.000 | Epsilon: 0.12
# Episode: [100000/8800]| Median progress: 8.00 | Median reward: 2.50 | Win rate : 0.000 | Epsilon: 0.11
# Episode: [100000/8900]| Median progress: 6.00 | Median reward: 2.50 | Win rate : 0.010 | Epsilon: 0.11
# Episode: [100000/9000]| Median progress: 6.00 | Median reward: 2.00 | Win rate : 0.020 | Epsilon: 0.11
# Episode: [100000/9100]| Median progress: 9.00 | Median reward: 3.50 | Win rate : 0.000 | Epsilon: 0.10
# Episode: [100000/9200]| Median progress: 8.00 | Median reward: 2.00 | Win rate : 0.020 | Epsilon: 0.10
# Episode: [100000/9300]| Median progress: 8.00 | Median reward: 3.00 | Win rate : 0.000 | Epsilon: 0.09
# Episode: [100000/9400]| Median progress: 7.00 | Median reward: 2.50 | Win rate : 0.000 | Epsilon: 0.09
# Episode: [100000/9500]| Median progress: 7.50 | Median reward: 1.50 | Win rate : 0.020 | Epsilon: 0.09
# Episode: [100000/9600]| Median progress: 6.50 | Median reward: 2.50 | Win rate : 0.010 | Epsilon: 0.08
# Episode: [100000/9700]| Median progress: 7.00 | Median reward: 1.75 | Win rate : 0.010 | Epsilon: 0.08
# Episode: [100000/9800]| Median progress: 7.50 | Median reward: 3.00 | Win rate : 0.020 | Epsilon: 0.08
# Episode: [100000/9900]| Median progress: 6.00 | Median reward: 1.50 | Win rate : 0.010 | Epsilon: 0.08
# Episode: [100000/10000]| Median progress: 8.00 | Median reward: 4.00 | Win rate : 0.010 | Epsilon: 0.07
# Episode: [100000/10100]| Median progress: 7.00 | Median reward: 2.00 | Win rate : 0.010 | Epsilon: 0.07
# Episode: [100000/10200]| Median progress: 6.00 | Median reward: 2.50 | Win rate : 0.000 | Epsilon: 0.07
# Episode: [100000/10300]| Median progress: 8.00 | Median reward: 2.50 | Win rate : 0.020 | Epsilon: 0.07
# Episode: [100000/10400]| Median progress: 9.00 | Median reward: 2.50 | Win rate : 0.040 | Epsilon: 0.06
# valid latest successed model
# Valid n:1000, Median progress: 7.00, Median reward: 4.50, Win rate : 0.006
# Valid n:1000, Median progress: 7.00, Median reward: 4.00, Win rate : 0.005
# Valid n:1000, Median progress: 7.00, Median reward: 4.00, Win rate : 0.003
# Valid n:1000, Median progress: 7.00, Median reward: 4.50, Win rate : 0.013
# Valid n:1000, Median progress: 7.00, Median reward: 4.00, Win rate : 0.012
# Valid n:1000, Median progress: 7.00, Median reward: 4.00, Win rate : 0.011
# Valid n:1000, Median progress: 7.00, Median reward: 4.50, Win rate : 0.009
# Valid n:1000, Median progress: 7.00, Median reward: 4.00, Win rate : 0.01
# Valid n:1000, Median progress: 6.00, Median reward: 3.50, Win rate : 0.006
# Valid n:1000, Median progress: 7.00, Median reward: 4.00, Win rate : 0.011
# Valid n:1000, Median progress: 7.00, Median reward: 4.00, Win rate : 0.007
# Episode: [100000/10500]| Median progress: 8.00 | Median reward: 2.75 | Win rate : 0.020 | Epsilon: 0.06
# Episode: [100000/10600]| Median progress: 8.00 | Median reward: 2.50 | Win rate : 0.010 | Epsilon: 0.06
# Episode: [100000/10700]| Median progress: 8.00 | Median reward: 2.50 | Win rate : 0.020 | Epsilon: 0.06
# Episode: [100000/10800]| Median progress: 7.50 | Median reward: 2.25 | Win rate : 0.010 | Epsilon: 0.06
# Episode: [100000/10900]| Median progress: 7.50 | Median reward: 1.50 | Win rate : 0.050 | Epsilon: 0.05
# valid latest successed model
# Valid n:1000, Median progress: 7.00, Median reward: 4.50, Win rate : 0.01
# Valid n:1000, Median progress: 8.00, Median reward: 4.50, Win rate : 0.007
# Valid n:1000, Median progress: 8.00, Median reward: 4.50, Win rate : 0.004
# Valid n:1000, Median progress: 8.00, Median reward: 4.50, Win rate : 0.012
# Valid n:1000, Median progress: 8.00, Median reward: 4.50, Win rate : 0.01
# Valid n:1000, Median progress: 8.00, Median reward: 4.50, Win rate : 0.009
# Valid n:1000, Median progress: 8.00, Median reward: 4.50, Win rate : 0.011
# Valid n:1000, Median progress: 8.00, Median reward: 4.50, Win rate : 0.013
# Valid n:1000, Median progress: 7.50, Median reward: 4.50, Win rate : 0.006
# Valid n:1000, Median progress: 8.00, Median reward: 4.50, Win rate : 0.013
# Valid n:1000, Median progress: 7.00, Median reward: 4.00, Win rate : 0.011
# Episode: [100000/11000]| Median progress: 9.00 | Median reward: 3.25 | Win rate : 0.010 | Epsilon: 0.05
# Episode: [100000/11100]| Median progress: 8.00 | Median reward: 3.25 | Win rate : 0.020 | Epsilon: 0.05
# Episode: [100000/11200]| Median progress: 7.00 | Median reward: 2.50 | Win rate : 0.020 | Epsilon: 0.05
# Episode: [100000/11300]| Median progress: 7.50 | Median reward: 2.50 | Win rate : 0.020 | Epsilon: 0.05
# Episode: [100000/11400]| Median progress: 8.00 | Median reward: 2.50 | Win rate : 0.000 | Epsilon: 0.04
# Episode: [100000/11500]| Median progress: 9.00 | Median reward: 2.75 | Win rate : 0.040 | Epsilon: 0.04
# Episode: [100000/11600]| Median progress: 7.00 | Median reward: 1.50 | Win rate : 0.000 | Epsilon: 0.04
# Episode: [100000/11700]| Median progress: 8.00 | Median reward: 3.50 | Win rate : 0.020 | Epsilon: 0.04
# Episode: [100000/11800]| Median progress: 9.00 | Median reward: 4.25 | Win rate : 0.030 | Epsilon: 0.04
# Episode: [100000/11900]| Median progress: 8.00 | Median reward: 2.50 | Win rate : 0.000 | Epsilon: 0.04
# Episode: [100000/12000]| Median progress: 7.00 | Median reward: 2.50 | Win rate : 0.020 | Epsilon: 0.04
# Episode: [100000/12100]| Median progress: 8.00 | Median reward: 3.25 | Win rate : 0.020 | Epsilon: 0.03
# Episode: [100000/12200]| Median progress: 9.00 | Median reward: 3.50 | Win rate : 0.030 | Epsilon: 0.03
# Episode: [100000/12300]| Median progress: 7.00 | Median reward: 2.50 | Win rate : 0.010 | Epsilon: 0.03
# Episode: [100000/12400]| Median progress: 8.00 | Median reward: 3.00 | Win rate : 0.030 | Epsilon: 0.03
# Episode: [100000/12500]| Median progress: 9.00 | Median reward: 3.50 | Win rate : 0.040 | Epsilon: 0.03
# Episode: [100000/12600]| Median progress: 7.00 | Median reward: 2.50 | Win rate : 0.030 | Epsilon: 0.03
# Episode: [100000/12700]| Median progress: 8.00 | Median reward: 3.00 | Win rate : 0.020 | Epsilon: 0.03
# Episode: [100000/12800]| Median progress: 7.50 | Median reward: 3.00 | Win rate : 0.040 | Epsilon: 0.02
# Episode: [100000/12900]| Median progress: 9.00 | Median reward: 3.00 | Win rate : 0.010 | Epsilon: 0.02
# Episode: [100000/13000]| Median progress: 9.00 | Median reward: 4.25 | Win rate : 0.050 | Epsilon: 0.02
# Episode: [100000/13100]| Median progress: 8.50 | Median reward: 4.00 | Win rate : 0.020 | Epsilon: 0.02
# Episode: [100000/13200]| Median progress: 8.00 | Median reward: 3.25 | Win rate : 0.030 | Epsilon: 0.02
# Episode: [100000/13300]| Median progress: 9.00 | Median reward: 2.75 | Win rate : 0.020 | Epsilon: 0.02
# Episode: [100000/13400]| Median progress: 7.00 | Median reward: 2.75 | Win rate : 0.020 | Epsilon: 0.02
# Episode: [100000/13500]| Median progress: 8.00 | Median reward: 3.50 | Win rate : 0.020 | Epsilon: 0.02
# Episode: [100000/13600]| Median progress: 9.00 | Median reward: 3.25 | Win rate : 0.000 | Epsilon: 0.02
# Episode: [100000/13700]| Median progress: 9.50 | Median reward: 3.50 | Win rate : 0.020 | Epsilon: 0.02
# Episode: [100000/13800]| Median progress: 10.00 | Median reward: 5.00 | Win rate : 0.030 | Epsilon: 0.01
# Episode: [100000/13900]| Median progress: 9.00 | Median reward: 4.25 | Win rate : 0.020 | Epsilon: 0.01
# Episode: [100000/14000]| Median progress: 9.00 | Median reward: 3.00 | Win rate : 0.030 | Epsilon: 0.01
# Episode: [100000/14100]| Median progress: 9.00 | Median reward: 3.75 | Win rate : 0.030 | Epsilon: 0.01
# Episode: [100000/14200]| Median progress: 9.50 | Median reward: 3.50 | Win rate : 0.060 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 8.00, Median reward: 5.00, Win rate : 0.026
# Valid n:1000, Median progress: 8.00, Median reward: 5.00, Win rate : 0.022
# Valid n:1000, Median progress: 8.00, Median reward: 5.00, Win rate : 0.02
# Valid n:1000, Median progress: 8.00, Median reward: 4.75, Win rate : 0.025
# Valid n:1000, Median progress: 8.00, Median reward: 4.75, Win rate : 0.03
# Valid n:1000, Median progress: 8.00, Median reward: 5.00, Win rate : 0.031
# Valid n:1000, Median progress: 8.00, Median reward: 4.75, Win rate : 0.025
# Valid n:1000, Median progress: 8.00, Median reward: 5.50, Win rate : 0.025
# Valid n:1000, Median progress: 8.00, Median reward: 4.50, Win rate : 0.021
# Valid n:1000, Median progress: 8.00, Median reward: 5.00, Win rate : 0.023
# Valid n:1000, Median progress: 8.00, Median reward: 5.00, Win rate : 0.026
# Episode: [100000/14300]| Median progress: 7.00 | Median reward: 3.00 | Win rate : 0.010 | Epsilon: 0.01
# Episode: [100000/14400]| Median progress: 6.00 | Median reward: 2.00 | Win rate : 0.050 | Epsilon: 0.01
# Episode: [100000/14500]| Median progress: 9.50 | Median reward: 3.50 | Win rate : 0.030 | Epsilon: 0.01
# Episode: [100000/14600]| Median progress: 7.50 | Median reward: 4.00 | Win rate : 0.040 | Epsilon: 0.01
# Episode: [100000/14700]| Median progress: 8.00 | Median reward: 2.50 | Win rate : 0.040 | Epsilon: 0.01
# Episode: [100000/14800]| Median progress: 10.00 | Median reward: 3.50 | Win rate : 0.090 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 9.00, Median reward: 5.50, Win rate : 0.026
# Valid n:1000, Median progress: 9.00, Median reward: 6.00, Win rate : 0.022
# Valid n:1000, Median progress: 8.00, Median reward: 5.50, Win rate : 0.033
# Valid n:1000, Median progress: 9.00, Median reward: 6.00, Win rate : 0.027
# Valid n:1000, Median progress: 9.00, Median reward: 5.50, Win rate : 0.032
# Valid n:1000, Median progress: 9.00, Median reward: 5.50, Win rate : 0.026
# Valid n:1000, Median progress: 8.00, Median reward: 5.50, Win rate : 0.028
# Valid n:1000, Median progress: 8.00, Median reward: 5.50, Win rate : 0.021
# Valid n:1000, Median progress: 8.50, Median reward: 5.50, Win rate : 0.031
# Valid n:1000, Median progress: 9.00, Median reward: 5.50, Win rate : 0.04
# Valid n:1000, Median progress: 8.00, Median reward: 5.00, Win rate : 0.031
# Episode: [100000/14900]| Median progress: 8.00 | Median reward: 3.25 | Win rate : 0.030 | Epsilon: 0.01
# Episode: [100000/15000]| Median progress: 8.50 | Median reward: 4.25 | Win rate : 0.010 | Epsilon: 0.01
# Episode: [100000/15100]| Median progress: 9.50 | Median reward: 4.00 | Win rate : 0.050 | Epsilon: 0.01
# Episode: [100000/15200]| Median progress: 9.00 | Median reward: 4.00 | Win rate : 0.050 | Epsilon: 0.01
# Episode: [100000/15300]| Median progress: 9.00 | Median reward: 2.50 | Win rate : 0.060 | Epsilon: 0.01
# Episode: [100000/15400]| Median progress: 9.50 | Median reward: 4.75 | Win rate : 0.050 | Epsilon: 0.01
# Episode: [100000/15500]| Median progress: 11.50 | Median reward: 4.00 | Win rate : 0.050 | Epsilon: 0.01
# Episode: [100000/15600]| Median progress: 9.00 | Median reward: 4.00 | Win rate : 0.070 | Epsilon: 0.01
# Episode: [100000/15700]| Median progress: 10.00 | Median reward: 5.50 | Win rate : 0.060 | Epsilon: 0.01
# Episode: [100000/15800]| Median progress: 8.00 | Median reward: 4.50 | Win rate : 0.060 | Epsilon: 0.01
# Episode: [100000/15900]| Median progress: 9.00 | Median reward: 4.50 | Win rate : 0.070 | Epsilon: 0.01
# Episode: [100000/16000]| Median progress: 11.00 | Median reward: 6.50 | Win rate : 0.060 | Epsilon: 0.01
# Episode: [100000/16100]| Median progress: 9.00 | Median reward: 3.75 | Win rate : 0.080 | Epsilon: 0.01
# Episode: [100000/16200]| Median progress: 9.00 | Median reward: 5.25 | Win rate : 0.080 | Epsilon: 0.01
# Episode: [100000/16300]| Median progress: 11.00 | Median reward: 5.00 | Win rate : 0.100 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 9.00, Median reward: 6.00, Win rate : 0.042
# Valid n:1000, Median progress: 9.00, Median reward: 6.50, Win rate : 0.043
# Valid n:1000, Median progress: 9.00, Median reward: 6.50, Win rate : 0.055
# Valid n:1000, Median progress: 9.00, Median reward: 6.00, Win rate : 0.053
# Valid n:1000, Median progress: 9.00, Median reward: 6.00, Win rate : 0.056
# Valid n:1000, Median progress: 9.00, Median reward: 6.00, Win rate : 0.047
# Valid n:1000, Median progress: 9.50, Median reward: 6.50, Win rate : 0.038
# Valid n:1000, Median progress: 9.00, Median reward: 6.00, Win rate : 0.036
# Valid n:1000, Median progress: 9.00, Median reward: 6.00, Win rate : 0.037
# Valid n:1000, Median progress: 10.00, Median reward: 6.50, Win rate : 0.059
# Valid n:1000, Median progress: 9.00, Median reward: 6.50, Win rate : 0.04
# Episode: [100000/16400]| Median progress: 12.00 | Median reward: 4.00 | Win rate : 0.070 | Epsilon: 0.01
# Episode: [100000/16500]| Median progress: 9.00 | Median reward: 3.75 | Win rate : 0.040 | Epsilon: 0.01
# Episode: [100000/16600]| Median progress: 9.00 | Median reward: 4.00 | Win rate : 0.100 | Epsilon: 0.01
# Episode: [100000/16700]| Median progress: 10.00 | Median reward: 6.00 | Win rate : 0.070 | Epsilon: 0.01
# Episode: [100000/16800]| Median progress: 11.00 | Median reward: 5.00 | Win rate : 0.030 | Epsilon: 0.01
# Episode: [100000/16900]| Median progress: 9.00 | Median reward: 4.25 | Win rate : 0.090 | Epsilon: 0.01
# Episode: [100000/17000]| Median progress: 9.00 | Median reward: 4.00 | Win rate : 0.070 | Epsilon: 0.01
# Episode: [100000/17100]| Median progress: 8.00 | Median reward: 4.00 | Win rate : 0.070 | Epsilon: 0.01
# Episode: [100000/17200]| Median progress: 8.50 | Median reward: 5.00 | Win rate : 0.080 | Epsilon: 0.01
# Episode: [100000/17300]| Median progress: 10.00 | Median reward: 3.50 | Win rate : 0.100 | Epsilon: 0.01
# Episode: [100000/17400]| Median progress: 11.00 | Median reward: 4.00 | Win rate : 0.060 | Epsilon: 0.01
# Episode: [100000/17500]| Median progress: 9.00 | Median reward: 3.50 | Win rate : 0.150 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 9.00, Median reward: 6.50, Win rate : 0.065
# Valid n:1000, Median progress: 10.00, Median reward: 7.00, Win rate : 0.08
# Valid n:1000, Median progress: 10.00, Median reward: 6.50, Win rate : 0.064
# Valid n:1000, Median progress: 9.00, Median reward: 6.50, Win rate : 0.077
# Valid n:1000, Median progress: 9.00, Median reward: 6.50, Win rate : 0.067
# Valid n:1000, Median progress: 9.00, Median reward: 6.50, Win rate : 0.065
# Valid n:1000, Median progress: 9.00, Median reward: 6.50, Win rate : 0.056
# Valid n:1000, Median progress: 10.00, Median reward: 7.00, Win rate : 0.062
# Valid n:1000, Median progress: 10.00, Median reward: 7.00, Win rate : 0.066
# Valid n:1000, Median progress: 9.00, Median reward: 5.50, Win rate : 0.048
# Valid n:1000, Median progress: 10.00, Median reward: 6.50, Win rate : 0.06
# Episode: [100000/17600]| Median progress: 10.00 | Median reward: 4.50 | Win rate : 0.050 | Epsilon: 0.01
# Episode: [100000/17700]| Median progress: 11.50 | Median reward: 5.50 | Win rate : 0.090 | Epsilon: 0.01
# Episode: [100000/17800]| Median progress: 11.50 | Median reward: 6.50 | Win rate : 0.040 | Epsilon: 0.01
# Episode: [100000/17900]| Median progress: 11.00 | Median reward: 5.75 | Win rate : 0.140 | Epsilon: 0.01
# Episode: [100000/18000]| Median progress: 10.00 | Median reward: 6.00 | Win rate : 0.140 | Epsilon: 0.01
# Episode: [100000/18100]| Median progress: 10.00 | Median reward: 4.00 | Win rate : 0.080 | Epsilon: 0.01
# Episode: [100000/18200]| Median progress: 12.00 | Median reward: 6.00 | Win rate : 0.100 | Epsilon: 0.01
# Episode: [100000/18300]| Median progress: 9.50 | Median reward: 3.50 | Win rate : 0.060 | Epsilon: 0.01
# Episode: [100000/18400]| Median progress: 11.00 | Median reward: 5.50 | Win rate : 0.060 | Epsilon: 0.01
# Episode: [100000/18500]| Median progress: 11.00 | Median reward: 6.00 | Win rate : 0.080 | Epsilon: 0.01
# Episode: [100000/18600]| Median progress: 10.50 | Median reward: 5.25 | Win rate : 0.140 | Epsilon: 0.01
# Episode: [100000/18700]| Median progress: 11.00 | Median reward: 6.50 | Win rate : 0.140 | Epsilon: 0.01
# Episode: [100000/18800]| Median progress: 11.00 | Median reward: 6.75 | Win rate : 0.130 | Epsilon: 0.01
# Episode: [100000/18900]| Median progress: 10.50 | Median reward: 4.75 | Win rate : 0.110 | Epsilon: 0.01
# Episode: [100000/19000]| Median progress: 10.00 | Median reward: 5.00 | Win rate : 0.030 | Epsilon: 0.01
# Episode: [100000/19100]| Median progress: 12.00 | Median reward: 4.50 | Win rate : 0.080 | Epsilon: 0.01
# Episode: [100000/19200]| Median progress: 11.50 | Median reward: 6.75 | Win rate : 0.160 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 10.00, Median reward: 7.00, Win rate : 0.102
# Valid n:1000, Median progress: 10.00, Median reward: 6.50, Win rate : 0.093
# Valid n:1000, Median progress: 10.00, Median reward: 7.50, Win rate : 0.107
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.101
# Valid n:1000, Median progress: 11.00, Median reward: 7.50, Win rate : 0.087
# Valid n:1000, Median progress: 10.00, Median reward: 7.00, Win rate : 0.088
# Valid n:1000, Median progress: 10.00, Median reward: 7.50, Win rate : 0.074
# Valid n:1000, Median progress: 10.00, Median reward: 7.00, Win rate : 0.083
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.102
# Valid n:1000, Median progress: 10.00, Median reward: 7.00, Win rate : 0.085
# Valid n:1000, Median progress: 9.00, Median reward: 6.50, Win rate : 0.087
# Episode: [100000/19300]| Median progress: 10.00 | Median reward: 6.50 | Win rate : 0.070 | Epsilon: 0.01
# Episode: [100000/19400]| Median progress: 12.50 | Median reward: 6.00 | Win rate : 0.140 | Epsilon: 0.01
# Episode: [100000/19500]| Median progress: 11.00 | Median reward: 6.00 | Win rate : 0.140 | Epsilon: 0.01
# Episode: [100000/19600]| Median progress: 11.00 | Median reward: 5.75 | Win rate : 0.140 | Epsilon: 0.01
# Episode: [100000/19700]| Median progress: 9.00 | Median reward: 4.50 | Win rate : 0.160 | Epsilon: 0.01
# Episode: [100000/19800]| Median progress: 11.00 | Median reward: 5.50 | Win rate : 0.190 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 10.00, Median reward: 7.50, Win rate : 0.121
# Valid n:1000, Median progress: 10.00, Median reward: 7.50, Win rate : 0.095
# Valid n:1000, Median progress: 10.00, Median reward: 7.50, Win rate : 0.106
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.134
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.113
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.099
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.104
# Valid n:1000, Median progress: 10.00, Median reward: 7.50, Win rate : 0.111
# Valid n:1000, Median progress: 10.00, Median reward: 7.50, Win rate : 0.093
# Valid n:1000, Median progress: 10.00, Median reward: 7.00, Win rate : 0.11
# Valid n:1000, Median progress: 10.00, Median reward: 7.50, Win rate : 0.112
# Episode: [100000/19900]| Median progress: 9.00 | Median reward: 4.25 | Win rate : 0.110 | Epsilon: 0.01
# Episode: [100000/20000]| Median progress: 13.00 | Median reward: 5.00 | Win rate : 0.170 | Epsilon: 0.01
# Episode: [100000/20100]| Median progress: 8.00 | Median reward: 4.00 | Win rate : 0.130 | Epsilon: 0.01
# Episode: [100000/20200]| Median progress: 10.50 | Median reward: 6.50 | Win rate : 0.150 | Epsilon: 0.01
# Episode: [100000/20300]| Median progress: 10.50 | Median reward: 5.75 | Win rate : 0.130 | Epsilon: 0.01
# Episode: [100000/20400]| Median progress: 10.00 | Median reward: 5.00 | Win rate : 0.130 | Epsilon: 0.01
# Episode: [100000/20500]| Median progress: 10.00 | Median reward: 5.50 | Win rate : 0.150 | Epsilon: 0.01
# Episode: [100000/20600]| Median progress: 12.00 | Median reward: 6.00 | Win rate : 0.190 | Epsilon: 0.01
# Episode: [100000/20700]| Median progress: 11.00 | Median reward: 5.75 | Win rate : 0.130 | Epsilon: 0.01
# Episode: [100000/20800]| Median progress: 10.00 | Median reward: 5.00 | Win rate : 0.180 | Epsilon: 0.01
# Episode: [100000/20900]| Median progress: 8.00 | Median reward: 4.75 | Win rate : 0.140 | Epsilon: 0.01
# Episode: [100000/21000]| Median progress: 13.00 | Median reward: 7.25 | Win rate : 0.230 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 11.00, Median reward: 8.25, Win rate : 0.152
# Valid n:1000, Median progress: 10.50, Median reward: 7.75, Win rate : 0.148
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.135
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.142
# Valid n:1000, Median progress: 10.00, Median reward: 7.50, Win rate : 0.14
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.119
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.137
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.153
# Valid n:1000, Median progress: 10.00, Median reward: 8.00, Win rate : 0.138
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.13
# Valid n:1000, Median progress: 10.00, Median reward: 7.50, Win rate : 0.137
# Episode: [100000/21100]| Median progress: 10.00 | Median reward: 3.75 | Win rate : 0.160 | Epsilon: 0.01
# Episode: [100000/21200]| Median progress: 12.00 | Median reward: 6.50 | Win rate : 0.190 | Epsilon: 0.01
# Episode: [100000/21300]| Median progress: 11.00 | Median reward: 6.50 | Win rate : 0.210 | Epsilon: 0.01
# Episode: [100000/21400]| Median progress: 12.00 | Median reward: 7.00 | Win rate : 0.220 | Epsilon: 0.01
# Episode: [100000/21500]| Median progress: 12.00 | Median reward: 6.25 | Win rate : 0.170 | Epsilon: 0.01
# Episode: [100000/21600]| Median progress: 11.00 | Median reward: 6.25 | Win rate : 0.160 | Epsilon: 0.01
# Episode: [100000/21700]| Median progress: 11.00 | Median reward: 7.00 | Win rate : 0.150 | Epsilon: 0.01
# Episode: [100000/21800]| Median progress: 11.00 | Median reward: 7.00 | Win rate : 0.210 | Epsilon: 0.01
# Episode: [100000/21900]| Median progress: 11.00 | Median reward: 7.00 | Win rate : 0.150 | Epsilon: 0.01
# Episode: [100000/22000]| Median progress: 10.00 | Median reward: 6.50 | Win rate : 0.150 | Epsilon: 0.01
# Episode: [100000/22100]| Median progress: 12.50 | Median reward: 8.75 | Win rate : 0.240 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.178
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.196
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.182
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.179
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.16
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.175
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.162
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.168
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.177
# Valid n:1000, Median progress: 12.00, Median reward: 9.00, Win rate : 0.172
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.189
# Episode: [100000/22200]| Median progress: 13.00 | Median reward: 7.75 | Win rate : 0.220 | Epsilon: 0.01
# Episode: [100000/22300]| Median progress: 13.00 | Median reward: 7.25 | Win rate : 0.180 | Epsilon: 0.01
# Episode: [100000/22400]| Median progress: 14.00 | Median reward: 8.00 | Win rate : 0.210 | Epsilon: 0.01
# Episode: [100000/22500]| Median progress: 11.50 | Median reward: 6.75 | Win rate : 0.170 | Epsilon: 0.01
# Episode: [100000/22600]| Median progress: 14.00 | Median reward: 9.00 | Win rate : 0.290 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 12.00, Median reward: 9.00, Win rate : 0.204
# Valid n:1000, Median progress: 12.00, Median reward: 8.75, Win rate : 0.181
# Valid n:1000, Median progress: 10.00, Median reward: 7.50, Win rate : 0.18
# Valid n:1000, Median progress: 12.00, Median reward: 9.00, Win rate : 0.207
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.196
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.168
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.193
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.196
# Valid n:1000, Median progress: 12.00, Median reward: 8.50, Win rate : 0.196
# Valid n:1000, Median progress: 11.00, Median reward: 9.00, Win rate : 0.204
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.191
# Episode: [100000/22700]| Median progress: 13.00 | Median reward: 7.75 | Win rate : 0.360 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.166
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.201
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.19
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.201
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.186
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.179
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.185
# Valid n:1000, Median progress: 11.00, Median reward: 8.00, Win rate : 0.19
# Valid n:1000, Median progress: 11.00, Median reward: 9.00, Win rate : 0.205
# Valid n:1000, Median progress: 12.00, Median reward: 8.50, Win rate : 0.183
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.2
# Episode: [100000/22800]| Median progress: 12.00 | Median reward: 7.50 | Win rate : 0.230 | Epsilon: 0.01
# Episode: [100000/22900]| Median progress: 11.00 | Median reward: 6.50 | Win rate : 0.240 | Epsilon: 0.01
# Episode: [100000/23000]| Median progress: 12.00 | Median reward: 7.75 | Win rate : 0.170 | Epsilon: 0.01
# Episode: [100000/23100]| Median progress: 10.00 | Median reward: 5.25 | Win rate : 0.210 | Epsilon: 0.01
# Episode: [100000/23200]| Median progress: 11.00 | Median reward: 7.00 | Win rate : 0.180 | Epsilon: 0.01
# Episode: [100000/23300]| Median progress: 11.50 | Median reward: 7.25 | Win rate : 0.280 | Epsilon: 0.01
# Episode: [100000/23400]| Median progress: 11.00 | Median reward: 8.25 | Win rate : 0.230 | Epsilon: 0.01
# Episode: [100000/23500]| Median progress: 13.00 | Median reward: 9.00 | Win rate : 0.190 | Epsilon: 0.01
# Episode: [100000/23600]| Median progress: 12.00 | Median reward: 7.50 | Win rate : 0.210 | Epsilon: 0.01
# Episode: [100000/23700]| Median progress: 12.50 | Median reward: 7.75 | Win rate : 0.320 | Epsilon: 0.01
# Episode: [100000/23800]| Median progress: 12.00 | Median reward: 8.50 | Win rate : 0.210 | Epsilon: 0.01
# Episode: [100000/23900]| Median progress: 12.00 | Median reward: 8.25 | Win rate : 0.270 | Epsilon: 0.01
# Episode: [100000/24000]| Median progress: 12.50 | Median reward: 8.00 | Win rate : 0.260 | Epsilon: 0.01
# Episode: [100000/24100]| Median progress: 13.00 | Median reward: 9.00 | Win rate : 0.350 | Epsilon: 0.01
# Episode: [100000/24200]| Median progress: 11.00 | Median reward: 7.00 | Win rate : 0.280 | Epsilon: 0.01
# Episode: [100000/24300]| Median progress: 14.00 | Median reward: 9.00 | Win rate : 0.270 | Epsilon: 0.01
# Episode: [100000/24400]| Median progress: 11.00 | Median reward: 7.50 | Win rate : 0.200 | Epsilon: 0.01
# Episode: [100000/24500]| Median progress: 12.00 | Median reward: 8.50 | Win rate : 0.250 | Epsilon: 0.01
# Episode: [100000/24600]| Median progress: 13.00 | Median reward: 8.75 | Win rate : 0.300 | Epsilon: 0.01
# Episode: [100000/24700]| Median progress: 9.00 | Median reward: 4.50 | Win rate : 0.220 | Epsilon: 0.01
# Episode: [100000/24800]| Median progress: 12.00 | Median reward: 7.75 | Win rate : 0.280 | Epsilon: 0.01
# Episode: [100000/24900]| Median progress: 11.50 | Median reward: 6.75 | Win rate : 0.200 | Epsilon: 0.01
# Episode: [100000/25000]| Median progress: 14.00 | Median reward: 10.75 | Win rate : 0.380 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.261
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.271
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.269
# Valid n:1000, Median progress: 11.00, Median reward: 8.50, Win rate : 0.243
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.277
# Valid n:1000, Median progress: 12.00, Median reward: 9.75, Win rate : 0.303
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.247
# Valid n:1000, Median progress: 13.00, Median reward: 10.50, Win rate : 0.272
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.262
# Valid n:1000, Median progress: 12.00, Median reward: 9.00, Win rate : 0.239
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.284
# Episode: [100000/25100]| Median progress: 13.00 | Median reward: 9.50 | Win rate : 0.430 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.297
# Valid n:1000, Median progress: 12.00, Median reward: 9.75, Win rate : 0.274
# Valid n:1000, Median progress: 12.00, Median reward: 10.00, Win rate : 0.292
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.327
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.282
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.263
# Valid n:1000, Median progress: 12.00, Median reward: 9.00, Win rate : 0.259
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.273
# Valid n:1000, Median progress: 12.00, Median reward: 9.50, Win rate : 0.263
# Valid n:1000, Median progress: 11.00, Median reward: 9.00, Win rate : 0.268
# Valid n:1000, Median progress: 13.00, Median reward: 10.50, Win rate : 0.272
# Episode: [100000/25200]| Median progress: 12.00 | Median reward: 8.50 | Win rate : 0.290 | Epsilon: 0.01
# Episode: [100000/25300]| Median progress: 11.00 | Median reward: 7.75 | Win rate : 0.270 | Epsilon: 0.01
# Episode: [100000/25400]| Median progress: 13.00 | Median reward: 9.50 | Win rate : 0.350 | Epsilon: 0.01
# Episode: [100000/25500]| Median progress: 12.00 | Median reward: 7.50 | Win rate : 0.320 | Epsilon: 0.01
# Episode: [100000/25600]| Median progress: 12.00 | Median reward: 7.50 | Win rate : 0.320 | Epsilon: 0.01
# Episode: [100000/25700]| Median progress: 11.00 | Median reward: 7.00 | Win rate : 0.300 | Epsilon: 0.01
# Episode: [100000/25800]| Median progress: 13.00 | Median reward: 9.50 | Win rate : 0.330 | Epsilon: 0.01
# Episode: [100000/25900]| Median progress: 13.00 | Median reward: 10.50 | Win rate : 0.330 | Epsilon: 0.01
# Episode: [100000/26000]| Median progress: 13.00 | Median reward: 9.50 | Win rate : 0.400 | Epsilon: 0.01
# Episode: [100000/26100]| Median progress: 12.00 | Median reward: 7.50 | Win rate : 0.280 | Epsilon: 0.01
# Episode: [100000/26200]| Median progress: 13.00 | Median reward: 9.75 | Win rate : 0.390 | Epsilon: 0.01
# Episode: [100000/26300]| Median progress: 14.00 | Median reward: 8.00 | Win rate : 0.370 | Epsilon: 0.01
# Episode: [100000/26400]| Median progress: 11.00 | Median reward: 8.25 | Win rate : 0.310 | Epsilon: 0.01
# Episode: [100000/26500]| Median progress: 12.50 | Median reward: 9.50 | Win rate : 0.330 | Epsilon: 0.01
# Episode: [100000/26600]| Median progress: 12.00 | Median reward: 8.50 | Win rate : 0.340 | Epsilon: 0.01
# Episode: [100000/26700]| Median progress: 14.00 | Median reward: 11.25 | Win rate : 0.400 | Epsilon: 0.01
# Episode: [100000/26800]| Median progress: 14.00 | Median reward: 10.75 | Win rate : 0.380 | Epsilon: 0.01
# Episode: [100000/26900]| Median progress: 13.00 | Median reward: 8.50 | Win rate : 0.360 | Epsilon: 0.01
# Episode: [100000/27000]| Median progress: 14.00 | Median reward: 9.75 | Win rate : 0.360 | Epsilon: 0.01
# Episode: [100000/27100]| Median progress: 13.00 | Median reward: 9.25 | Win rate : 0.340 | Epsilon: 0.01
# Episode: [100000/27200]| Median progress: 13.00 | Median reward: 8.50 | Win rate : 0.360 | Epsilon: 0.01
# Episode: [100000/27300]| Median progress: 14.00 | Median reward: 10.25 | Win rate : 0.370 | Epsilon: 0.01
# Episode: [100000/27400]| Median progress: 11.50 | Median reward: 9.50 | Win rate : 0.320 | Epsilon: 0.01
# Episode: [100000/27500]| Median progress: 14.00 | Median reward: 11.00 | Win rate : 0.430 | Epsilon: 0.01
# Episode: [100000/27600]| Median progress: 11.00 | Median reward: 8.50 | Win rate : 0.420 | Epsilon: 0.01
# Episode: [100000/27700]| Median progress: 13.00 | Median reward: 9.75 | Win rate : 0.380 | Epsilon: 0.01
# Episode: [100000/27800]| Median progress: 13.00 | Median reward: 10.75 | Win rate : 0.310 | Epsilon: 0.01
# Episode: [100000/27900]| Median progress: 14.00 | Median reward: 11.25 | Win rate : 0.380 | Epsilon: 0.01
# Episode: [100000/28000]| Median progress: 11.00 | Median reward: 8.50 | Win rate : 0.300 | Epsilon: 0.01
# Episode: [100000/28100]| Median progress: 12.50 | Median reward: 9.50 | Win rate : 0.440 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 13.00, Median reward: 11.00, Win rate : 0.347
# Valid n:1000, Median progress: 13.00, Median reward: 11.00, Win rate : 0.346
# Valid n:1000, Median progress: 13.00, Median reward: 10.50, Win rate : 0.36
# Valid n:1000, Median progress: 13.00, Median reward: 10.50, Win rate : 0.334
# Valid n:1000, Median progress: 12.00, Median reward: 10.25, Win rate : 0.353
# Valid n:1000, Median progress: 13.00, Median reward: 10.50, Win rate : 0.325
# Valid n:1000, Median progress: 12.00, Median reward: 10.50, Win rate : 0.322
# Valid n:1000, Median progress: 13.00, Median reward: 10.50, Win rate : 0.359
# Valid n:1000, Median progress: 13.00, Median reward: 11.00, Win rate : 0.352
# Valid n:1000, Median progress: 13.00, Median reward: 10.50, Win rate : 0.346
# Valid n:1000, Median progress: 13.00, Median reward: 10.50, Win rate : 0.327
# Episode: [100000/28200]| Median progress: 14.50 | Median reward: 11.75 | Win rate : 0.370 | Epsilon: 0.01
# Episode: [100000/28300]| Median progress: 14.50 | Median reward: 11.00 | Win rate : 0.410 | Epsilon: 0.01
# Episode: [100000/28400]| Median progress: 14.00 | Median reward: 10.50 | Win rate : 0.350 | Epsilon: 0.01
# Episode: [100000/28500]| Median progress: 13.00 | Median reward: 9.00 | Win rate : 0.300 | Epsilon: 0.01
# Episode: [100000/28600]| Median progress: 11.00 | Median reward: 8.50 | Win rate : 0.390 | Epsilon: 0.01
# Episode: [100000/28700]| Median progress: 12.00 | Median reward: 8.00 | Win rate : 0.400 | Epsilon: 0.01
# Episode: [100000/28800]| Median progress: 12.50 | Median reward: 8.00 | Win rate : 0.410 | Epsilon: 0.01
# Episode: [100000/28900]| Median progress: 12.50 | Median reward: 9.50 | Win rate : 0.260 | Epsilon: 0.01
# Episode: [100000/29000]| Median progress: 13.00 | Median reward: 11.00 | Win rate : 0.430 | Epsilon: 0.01
# Episode: [100000/29100]| Median progress: 13.00 | Median reward: 10.00 | Win rate : 0.410 | Epsilon: 0.01
# Episode: [100000/29200]| Median progress: 15.00 | Median reward: 11.25 | Win rate : 0.450 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 13.00, Median reward: 11.00, Win rate : 0.38
# Valid n:1000, Median progress: 12.00, Median reward: 10.00, Win rate : 0.388
# Valid n:1000, Median progress: 13.00, Median reward: 10.50, Win rate : 0.392
# Valid n:1000, Median progress: 13.00, Median reward: 10.50, Win rate : 0.372
# Valid n:1000, Median progress: 14.00, Median reward: 11.50, Win rate : 0.409
# Valid n:1000, Median progress: 13.00, Median reward: 11.00, Win rate : 0.373
# Valid n:1000, Median progress: 12.50, Median reward: 10.50, Win rate : 0.374
# Valid n:1000, Median progress: 14.00, Median reward: 11.50, Win rate : 0.402
# Valid n:1000, Median progress: 14.00, Median reward: 11.50, Win rate : 0.406
# Valid n:1000, Median progress: 13.00, Median reward: 11.00, Win rate : 0.381
# Valid n:1000, Median progress: 13.00, Median reward: 10.50, Win rate : 0.392
# Episode: [100000/29300]| Median progress: 13.50 | Median reward: 9.75 | Win rate : 0.310 | Epsilon: 0.01
# Episode: [100000/29400]| Median progress: 12.50 | Median reward: 9.50 | Win rate : 0.350 | Epsilon: 0.01
# Episode: [100000/29500]| Median progress: 13.00 | Median reward: 8.50 | Win rate : 0.390 | Epsilon: 0.01
# Episode: [100000/29600]| Median progress: 13.50 | Median reward: 10.50 | Win rate : 0.430 | Epsilon: 0.01
# Episode: [100000/29700]| Median progress: 14.00 | Median reward: 10.75 | Win rate : 0.410 | Epsilon: 0.01
# Episode: [100000/29800]| Median progress: 13.00 | Median reward: 10.75 | Win rate : 0.420 | Epsilon: 0.01
# Episode: [100000/29900]| Median progress: 13.00 | Median reward: 10.25 | Win rate : 0.410 | Epsilon: 0.01
# Episode: [100000/30000]| Median progress: 14.00 | Median reward: 10.25 | Win rate : 0.420 | Epsilon: 0.01
# Episode: [100000/30100]| Median progress: 15.00 | Median reward: 10.50 | Win rate : 0.320 | Epsilon: 0.01
# Episode: [100000/30200]| Median progress: 11.00 | Median reward: 8.25 | Win rate : 0.310 | Epsilon: 0.01
# Episode: [100000/30300]| Median progress: 13.00 | Median reward: 10.50 | Win rate : 0.420 | Epsilon: 0.01
# ...
# Valid n:1000, Median progress: 15.00, Median reward: 14.00, Win rate : 0.62
# Valid n:1000, Median progress: 15.00, Median reward: 14.00, Win rate : 0.602
# Valid n:1000, Median progress: 15.00, Median reward: 13.50, Win rate : 0.584
# Valid n:1000, Median progress: 15.00, Median reward: 13.50, Win rate : 0.59
# Valid n:1000, Median progress: 15.00, Median reward: 14.50, Win rate : 0.61
# Episode: [100000/76000]| Median progress: 16.50 | Median reward: 14.25 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/76100]| Median progress: 14.00 | Median reward: 12.75 | Win rate : 0.550 | Epsilon: 0.01
# Episode: [100000/76200]| Median progress: 15.50 | Median reward: 13.50 | Win rate : 0.580 | Epsilon: 0.01
# Episode: [100000/76300]| Median progress: 15.50 | Median reward: 13.50 | Win rate : 0.670 | Epsilon: 0.01
# Episode: [100000/76400]| Median progress: 15.50 | Median reward: 13.50 | Win rate : 0.570 | Epsilon: 0.01
# Episode: [100000/76500]| Median progress: 15.50 | Median reward: 13.50 | Win rate : 0.590 | Epsilon: 0.01
# Episode: [100000/76600]| Median progress: 14.00 | Median reward: 12.50 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/76700]| Median progress: 14.50 | Median reward: 12.50 | Win rate : 0.550 | Epsilon: 0.01
# Episode: [100000/76800]| Median progress: 17.00 | Median reward: 14.75 | Win rate : 0.590 | Epsilon: 0.01
# Episode: [100000/76900]| Median progress: 16.00 | Median reward: 15.50 | Win rate : 0.680 | Epsilon: 0.01
# Episode: [100000/77000]| Median progress: 16.00 | Median reward: 15.50 | Win rate : 0.730 | Epsilon: 0.01
# Episode: [100000/77100]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/77200]| Median progress: 16.00 | Median reward: 14.00 | Win rate : 0.620 | Epsilon: 0.01
# Episode: [100000/77300]| Median progress: 17.00 | Median reward: 14.50 | Win rate : 0.620 | Epsilon: 0.01
# Episode: [100000/77400]| Median progress: 15.00 | Median reward: 14.25 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/77500]| Median progress: 15.00 | Median reward: 13.50 | Win rate : 0.570 | Epsilon: 0.01
# Episode: [100000/77600]| Median progress: 16.50 | Median reward: 14.75 | Win rate : 0.620 | Epsilon: 0.01
# Episode: [100000/77700]| Median progress: 15.00 | Median reward: 13.50 | Win rate : 0.630 | Epsilon: 0.01
# Episode: [100000/77800]| Median progress: 15.00 | Median reward: 14.50 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/77900]| Median progress: 15.00 | Median reward: 14.50 | Win rate : 0.640 | Epsilon: 0.01
# Episode: [100000/78000]| Median progress: 18.00 | Median reward: 15.50 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/78100]| Median progress: 17.50 | Median reward: 14.75 | Win rate : 0.590 | Epsilon: 0.01
# Episode: [100000/78200]| Median progress: 14.50 | Median reward: 13.00 | Win rate : 0.690 | Epsilon: 0.01
# Episode: [100000/78300]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.630 | Epsilon: 0.01
# Episode: [100000/78400]| Median progress: 16.00 | Median reward: 13.25 | Win rate : 0.590 | Epsilon: 0.01
# Episode: [100000/78500]| Median progress: 15.00 | Median reward: 12.50 | Win rate : 0.560 | Epsilon: 0.01
# Episode: [100000/78600]| Median progress: 17.00 | Median reward: 14.00 | Win rate : 0.690 | Epsilon: 0.01
# Episode: [100000/78700]| Median progress: 16.50 | Median reward: 14.75 | Win rate : 0.640 | Epsilon: 0.01
# Episode: [100000/78800]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.620 | Epsilon: 0.01
# Episode: [100000/78900]| Median progress: 15.00 | Median reward: 14.25 | Win rate : 0.640 | Epsilon: 0.01
# Episode: [100000/79000]| Median progress: 16.00 | Median reward: 15.00 | Win rate : 0.710 | Epsilon: 0.01
# Episode: [100000/79100]| Median progress: 15.00 | Median reward: 13.25 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/79200]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.630 | Epsilon: 0.01
# Episode: [100000/79300]| Median progress: 15.00 | Median reward: 12.75 | Win rate : 0.640 | Epsilon: 0.01
# Episode: [100000/79400]| Median progress: 16.00 | Median reward: 13.50 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/79500]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.660 | Epsilon: 0.01
# Episode: [100000/79600]| Median progress: 16.50 | Median reward: 14.50 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/79700]| Median progress: 16.00 | Median reward: 14.75 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/79800]| Median progress: 17.50 | Median reward: 14.75 | Win rate : 0.610 | Epsilon: 0.01
# Episode: [100000/79900]| Median progress: 16.00 | Median reward: 14.25 | Win rate : 0.670 | Epsilon: 0.01
# Episode: [100000/80000]| Median progress: 17.00 | Median reward: 15.50 | Win rate : 0.670 | Epsilon: 0.01
# Episode: [100000/80100]| Median progress: 16.00 | Median reward: 13.75 | Win rate : 0.630 | Epsilon: 0.01
# Episode: [100000/80200]| Median progress: 16.00 | Median reward: 15.00 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/80300]| Median progress: 17.00 | Median reward: 16.25 | Win rate : 0.690 | Epsilon: 0.01
# Episode: [100000/80400]| Median progress: 16.00 | Median reward: 15.00 | Win rate : 0.640 | Epsilon: 0.01
# Episode: [100000/80500]| Median progress: 18.00 | Median reward: 16.00 | Win rate : 0.640 | Epsilon: 0.01
# Episode: [100000/80600]| Median progress: 16.50 | Median reward: 14.50 | Win rate : 0.700 | Epsilon: 0.01
# Episode: [100000/80700]| Median progress: 15.00 | Median reward: 13.50 | Win rate : 0.550 | Epsilon: 0.01
# Episode: [100000/80800]| Median progress: 17.00 | Median reward: 15.50 | Win rate : 0.730 | Epsilon: 0.01
# Episode: [100000/80900]| Median progress: 14.00 | Median reward: 12.50 | Win rate : 0.630 | Epsilon: 0.01
# Episode: [100000/81000]| Median progress: 16.00 | Median reward: 13.50 | Win rate : 0.640 | Epsilon: 0.01
# Episode: [100000/81100]| Median progress: 14.00 | Median reward: 12.50 | Win rate : 0.570 | Epsilon: 0.01
# Episode: [100000/81200]| Median progress: 16.00 | Median reward: 13.75 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/81300]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/81400]| Median progress: 17.00 | Median reward: 15.75 | Win rate : 0.630 | Epsilon: 0.01
# Episode: [100000/81500]| Median progress: 16.00 | Median reward: 14.75 | Win rate : 0.680 | Epsilon: 0.01
# Episode: [100000/81600]| Median progress: 18.00 | Median reward: 16.75 | Win rate : 0.700 | Epsilon: 0.01
# Episode: [100000/81700]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.670 | Epsilon: 0.01
# Episode: [100000/81800]| Median progress: 16.00 | Median reward: 15.50 | Win rate : 0.630 | Epsilon: 0.01
# Episode: [100000/81900]| Median progress: 16.00 | Median reward: 13.50 | Win rate : 0.560 | Epsilon: 0.01
# Episode: [100000/82000]| Median progress: 16.00 | Median reward: 13.50 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/82100]| Median progress: 17.00 | Median reward: 14.00 | Win rate : 0.640 | Epsilon: 0.01
# Episode: [100000/82200]| Median progress: 15.00 | Median reward: 14.25 | Win rate : 0.570 | Epsilon: 0.01
# Episode: [100000/82300]| Median progress: 16.50 | Median reward: 15.50 | Win rate : 0.700 | Epsilon: 0.01
# Episode: [100000/82400]| Median progress: 15.00 | Median reward: 13.50 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/82500]| Median progress: 16.00 | Median reward: 15.00 | Win rate : 0.680 | Epsilon: 0.01
# Episode: [100000/82600]| Median progress: 16.50 | Median reward: 14.50 | Win rate : 0.610 | Epsilon: 0.01
# Episode: [100000/82700]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.670 | Epsilon: 0.01
# Episode: [100000/82800]| Median progress: 17.00 | Median reward: 14.50 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/82900]| Median progress: 14.50 | Median reward: 13.00 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/83000]| Median progress: 16.00 | Median reward: 14.00 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/83100]| Median progress: 16.00 | Median reward: 13.50 | Win rate : 0.670 | Epsilon: 0.01
# Episode: [100000/83200]| Median progress: 14.00 | Median reward: 12.50 | Win rate : 0.620 | Epsilon: 0.01
# Episode: [100000/83300]| Median progress: 18.00 | Median reward: 16.75 | Win rate : 0.620 | Epsilon: 0.01
# Episode: [100000/83400]| Median progress: 16.50 | Median reward: 14.50 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/83500]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.610 | Epsilon: 0.01
# Episode: [100000/83600]| Median progress: 15.50 | Median reward: 14.50 | Win rate : 0.640 | Epsilon: 0.01
# Episode: [100000/83700]| Median progress: 15.00 | Median reward: 13.75 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/83800]| Median progress: 15.50 | Median reward: 13.50 | Win rate : 0.580 | Epsilon: 0.01
# Episode: [100000/83900]| Median progress: 15.00 | Median reward: 13.75 | Win rate : 0.590 | Epsilon: 0.01
# Episode: [100000/84000]| Median progress: 16.50 | Median reward: 15.25 | Win rate : 0.640 | Epsilon: 0.01
# Episode: [100000/84100]| Median progress: 16.00 | Median reward: 14.25 | Win rate : 0.620 | Epsilon: 0.01
# Episode: [100000/84200]| Median progress: 17.00 | Median reward: 15.50 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/84300]| Median progress: 16.00 | Median reward: 13.50 | Win rate : 0.630 | Epsilon: 0.01
# Episode: [100000/84400]| Median progress: 16.50 | Median reward: 15.00 | Win rate : 0.700 | Epsilon: 0.01
# Episode: [100000/84500]| Median progress: 15.00 | Median reward: 13.50 | Win rate : 0.570 | Epsilon: 0.01
# Episode: [100000/84600]| Median progress: 15.50 | Median reward: 14.50 | Win rate : 0.680 | Epsilon: 0.01
# Episode: [100000/84700]| Median progress: 15.00 | Median reward: 13.50 | Win rate : 0.590 | Epsilon: 0.01
# Episode: [100000/84800]| Median progress: 17.00 | Median reward: 15.75 | Win rate : 0.680 | Epsilon: 0.01
# Episode: [100000/84900]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.620 | Epsilon: 0.01
# Episode: [100000/85000]| Median progress: 17.00 | Median reward: 15.00 | Win rate : 0.610 | Epsilon: 0.01
# Episode: [100000/85100]| Median progress: 16.00 | Median reward: 13.75 | Win rate : 0.570 | Epsilon: 0.01
# Episode: [100000/85200]| Median progress: 15.00 | Median reward: 13.50 | Win rate : 0.680 | Epsilon: 0.01
# Episode: [100000/85300]| Median progress: 16.00 | Median reward: 15.50 | Win rate : 0.670 | Epsilon: 0.01
# Episode: [100000/85400]| Median progress: 16.00 | Median reward: 13.75 | Win rate : 0.660 | Epsilon: 0.01
# Episode: [100000/85500]| Median progress: 16.00 | Median reward: 14.00 | Win rate : 0.560 | Epsilon: 0.01
# Episode: [100000/85600]| Median progress: 14.00 | Median reward: 13.50 | Win rate : 0.570 | Epsilon: 0.01
# Episode: [100000/85700]| Median progress: 16.00 | Median reward: 15.50 | Win rate : 0.660 | Epsilon: 0.01
# Episode: [100000/85800]| Median progress: 14.00 | Median reward: 13.25 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/85900]| Median progress: 14.00 | Median reward: 12.50 | Win rate : 0.590 | Epsilon: 0.01
# Episode: [100000/86000]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.610 | Epsilon: 0.01
# Episode: [100000/86100]| Median progress: 18.00 | Median reward: 16.50 | Win rate : 0.730 | Epsilon: 0.01
# Episode: [100000/86200]| Median progress: 15.00 | Median reward: 13.75 | Win rate : 0.560 | Epsilon: 0.01
# Episode: [100000/86300]| Median progress: 15.00 | Median reward: 13.50 | Win rate : 0.610 | Epsilon: 0.01
# Episode: [100000/86400]| Median progress: 17.00 | Median reward: 14.75 | Win rate : 0.580 | Epsilon: 0.01
# Episode: [100000/86500]| Median progress: 15.00 | Median reward: 14.25 | Win rate : 0.710 | Epsilon: 0.01
# Episode: [100000/86600]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.700 | Epsilon: 0.01
# Episode: [100000/86700]| Median progress: 16.00 | Median reward: 14.25 | Win rate : 0.580 | Epsilon: 0.01
# Episode: [100000/86800]| Median progress: 17.00 | Median reward: 15.50 | Win rate : 0.690 | Epsilon: 0.01
# Episode: [100000/86900]| Median progress: 14.00 | Median reward: 11.50 | Win rate : 0.530 | Epsilon: 0.01
# Episode: [100000/87000]| Median progress: 17.00 | Median reward: 15.50 | Win rate : 0.620 | Epsilon: 0.01
# Episode: [100000/87100]| Median progress: 14.00 | Median reward: 12.75 | Win rate : 0.570 | Epsilon: 0.01
# Episode: [100000/87200]| Median progress: 17.00 | Median reward: 15.75 | Win rate : 0.710 | Epsilon: 0.01
# Episode: [100000/87300]| Median progress: 15.50 | Median reward: 13.75 | Win rate : 0.530 | Epsilon: 0.01
# Episode: [100000/87400]| Median progress: 16.50 | Median reward: 15.00 | Win rate : 0.670 | Epsilon: 0.01
# Episode: [100000/87500]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.670 | Epsilon: 0.01
# Episode: [100000/87600]| Median progress: 15.50 | Median reward: 14.50 | Win rate : 0.640 | Epsilon: 0.01
# Episode: [100000/87700]| Median progress: 17.50 | Median reward: 16.25 | Win rate : 0.740 | Epsilon: 0.01
# Episode: [100000/87800]| Median progress: 17.00 | Median reward: 15.50 | Win rate : 0.680 | Epsilon: 0.01
# Episode: [100000/87900]| Median progress: 15.00 | Median reward: 12.50 | Win rate : 0.540 | Epsilon: 0.01
# Episode: [100000/88000]| Median progress: 14.00 | Median reward: 13.50 | Win rate : 0.590 | Epsilon: 0.01
# Episode: [100000/88100]| Median progress: 17.00 | Median reward: 15.50 | Win rate : 0.750 | Epsilon: 0.01
# valid latest successed model
# Valid n:1000, Median progress: 16.00, Median reward: 15.25, Win rate : 0.639
# Valid n:1000, Median progress: 16.00, Median reward: 15.00, Win rate : 0.648
# Valid n:1000, Median progress: 16.00, Median reward: 15.00, Win rate : 0.644
# Valid n:1000, Median progress: 16.00, Median reward: 15.50, Win rate : 0.651
# Valid n:1000, Median progress: 16.00, Median reward: 15.50, Win rate : 0.649
# Valid n:1000, Median progress: 16.00, Median reward: 15.00, Win rate : 0.632
# Valid n:1000, Median progress: 16.00, Median reward: 15.00, Win rate : 0.652
# Valid n:1000, Median progress: 16.00, Median reward: 14.75, Win rate : 0.65
# Valid n:1000, Median progress: 16.00, Median reward: 15.50, Win rate : 0.652
# Valid n:1000, Median progress: 16.00, Median reward: 15.50, Win rate : 0.65
# Valid n:1000, Median progress: 16.00, Median reward: 15.00, Win rate : 0.646
# Episode: [100000/88200]| Median progress: 17.00 | Median reward: 15.50 | Win rate : 0.670 | Epsilon: 0.01
# Episode: [100000/88300]| Median progress: 15.00 | Median reward: 14.00 | Win rate : 0.630 | Epsilon: 0.01
# Episode: [100000/88400]| Median progress: 16.00 | Median reward: 15.25 | Win rate : 0.590 | Epsilon: 0.01
# Episode: [100000/88500]| Median progress: 17.00 | Median reward: 15.50 | Win rate : 0.690 | Epsilon: 0.01
# Episode: [100000/88600]| Median progress: 17.00 | Median reward: 16.50 | Win rate : 0.680 | Epsilon: 0.01
# Episode: [100000/88700]| Median progress: 16.00 | Median reward: 15.50 | Win rate : 0.680 | Epsilon: 0.01
# Episode: [100000/88800]| Median progress: 15.00 | Median reward: 13.50 | Win rate : 0.550 | Epsilon: 0.01
# Episode: [100000/88900]| Median progress: 13.00 | Median reward: 12.50 | Win rate : 0.650 | Epsilon: 0.01
# Episode: [100000/89000]| Median progress: 15.00 | Median reward: 13.50 | Win rate : 0.600 | Epsilon: 0.01
# Episode: [100000/89100]| Median progress: 14.00 | Median reward: 13.00 | Win rate : 0.620 | Epsilon: 0.01
# Episode: [100000/89200]| Median progress: 14.00 | Median reward: 13.00 | Win rate : 0.580 | Epsilon: 0.01
# Episode: [100000/89300]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.610 | Epsilon: 0.01
# Episode: [100000/89400]| Median progress: 16.00 | Median reward: 14.50 | Win rate : 0.580 | Epsilon: 0.01
# Episode: [100000/89500]| Median progress: 16.00 | Median reward: 14.25 | Win rate : 0.560 | Epsilon: 0.01
# Episode: [100000/89600]| Median progress: 16.50 | Median reward: 14.00 | Win rate : 0.660 | Epsilon: 0.01
# Episode: [100000/89700]| Median progress: 14.00 | Median reward: 12.25 | Win rate : 0.540 | Epsilon: 0.01
# Episode: [100000/89800]| Median progress: 17.00 | Median reward: 15.50 | Win rate : 0.660 | Epsilon: 0.01

# %%
with open(os.path.join(trainer.total_path, f'{len(trainer.progress_list)}'), "wb") as f:
    pickle.dump(trainer, f)

# %%
trainer.train()
trainer.visualize_train()
trainer.save_model()

# %%
trainer.train()
trainer.visualize_train()
trainer.save_model()

# %% [markdown]
# # 03 Tester

# %% [markdown]
# ## def tester env, agent

# %%
tester_env = LimitedMinesweeperEnv(map_size=level['easy']['map_size'],
                                    n_mines=level['easy']['n_mines'],
                                    train=False)

tester_agent = Agent(env=tester_env,
                        net=net,
                        MEM_SIZE=MEM_SIZE,
                        MEM_SIZE_MIN=MEM_SIZE_MIN,
                        BATCH_SIZE=BATCH_SIZE,
                        LEARNING_RATE=LEARNING_RATE,
                        LEARN_DECAY=LEARN_DECAY,
                        LEARN_MIN=LEARN_MIN,
                        DISCOUNT=DISCOUNT,
                        EPSILON=EPSILON,
                        EPSILON_DECAY=EPSILON_DECAY,
                        EPSILON_MIN=EPSILON_MIN,
                        UPDATE_TARGET_EVERY=UPDATE_TARGET_EVERY)

# %% [markdown]
# ## def tester

# %% [markdown]
# ### fixed

# %%
tester = PerformTester(tester_agent, tester_env, tester_env.n_boards, trainer.save_point['best_model_valid'])

# %%
tester = PerformTester(tester_agent, tester_env, tester_env.n_boards, trainer.save_point['best_model_train'])

# %%
tester = PerformTester(tester_agent, tester_env, tester_env.n_boards, trainer.save_point['final_model'])

# %%
tester = PerformTester(tester_agent, tester_env, tester_env.n_boards, trainer.save_point['best_model_successed'])

# %% [markdown]
# ### random

# %%
tester = PerformTester(tester_agent, env, 1000, trainer.save_point['best_model_valid'])

# %%
tester = PerformTester(tester_agent, env, 1000, trainer.save_point['best_model_train'])

# %%
tester = PerformTester(tester_agent, env, 1000, trainer.save_point['final_model'])

# %%
tester = PerformTester(tester_agent, env, 1000, trainer.save_point['best_model_successed'])

# %% [markdown]
# ### random

# %%
tester = PerformTester(tester_agent, env, 1000, trainer.save_point['best_model_valid'])

# %%
tester = PerformTester(tester_agent, env, 1000, trainer.save_point['best_model_train'])

# %%
tester = PerformTester(tester_agent, env, 1000, trainer.save_point['final_model'])

# %%
tester = PerformTester(tester_agent, env, 1000, trainer.save_point['best_model_successed'])

# %% [markdown]
# ## 진 케이스 시각화

# %%
target_done = tester.lost_game_done
idx_iteration = iter(range(len(target_done)))

# %%
idx = next(idx_iteration)
tester.visualize_single_step(target_done.iloc[idx])

# %%
target_iter = tester.lost_game_per_epi

# %%
epi, epi_df = next(target_iter)

tester.replay_single_episode(epi_df)

# %%
tester.lost_more18_percent

# %% [markdown]
# ## 승리한 케이스 시각화

# %%
target_done = tester.won_game_done
idx_iteration = iter(range(len(target_done)))

# %%
idx = next(idx_iteration)
tester.visualize_single_step(target_done.iloc[idx])

# %%
target_iter = tester.won_game_per_epi

# %%
epi, epi_df = next(target_iter)
tester.replay_single_episode(epi_df)

# %% [markdown]
# # etc

# %%
# Learning settings
BATCH_SIZE = 4

# env = MinesweeperEnv(map_size=(4,4),
#                      n_mines=2)

env = MinesweeperEnv(map_size=level['easy']['map_size'],
                     n_mines=level['easy']['n_mines'])

net = Net(input_dims=env.state.shape,
          n_actions=env.total_tiles,
          conv_units=CONV_UNITS)

agent = Agent(env=env,
                        net=net,
                        MEM_SIZE=MEM_SIZE,
                        MEM_SIZE_MIN=MEM_SIZE_MIN,
                        BATCH_SIZE=BATCH_SIZE,
                        LEARNING_RATE=LEARNING_RATE,
                        LEARN_DECAY=LEARN_DECAY,
                        LEARN_MIN=LEARN_MIN,
                        DISCOUNT=DISCOUNT,
                        EPSILON=EPSILON,
                        EPSILON_DECAY=EPSILON_DECAY,
                        EPSILON_MIN=EPSILON_MIN,
                        UPDATE_TARGET_EVERY=UPDATE_TARGET_EVERY)

# agent = Limited18Agent(env=env,
#                         net=net,
#                         MEM_SIZE=MEM_SIZE,
#                         MEM_SIZE_MIN=MEM_SIZE_MIN,
#                         BATCH_SIZE=BATCH_SIZE,
#                         LEARNING_RATE=LEARNING_RATE,
#                         LEARN_DECAY=LEARN_DECAY,
#                         LEARN_MIN=LEARN_MIN,
#                         DISCOUNT=DISCOUNT,
#                         EPSILON=EPSILON,
#                         EPSILON_DECAY=EPSILON_DECAY,
#                         EPSILON_MIN=EPSILON_MIN,
#                         UPDATE_TARGET_EVERY=UPDATE_TARGET_EVERY)

tester_agent = Agent(env=env,
                    net=net,
                    MEM_SIZE=MEM_SIZE,
                    MEM_SIZE_MIN=MEM_SIZE_MIN,
                    BATCH_SIZE=BATCH_SIZE,
                    LEARNING_RATE=LEARNING_RATE,
                    LEARN_DECAY=LEARN_DECAY,
                    LEARN_MIN=LEARN_MIN,
                    DISCOUNT=DISCOUNT,
                    EPSILON=EPSILON,
                    EPSILON_DECAY=EPSILON_DECAY,
                    EPSILON_MIN=EPSILON_MIN,
                    UPDATE_TARGET_EVERY=UPDATE_TARGET_EVERY)

trainer = Trainer(env=env,
                    agent=agent,
                    tester_agent=tester_agent,
                    name='episodeInterval',
                    train_start=True,
                    EPISODES = EPISODES,
                    PRINT_INTERVAL = PRINT_INTERVAL,
                    TRAIN_RENDER = TRAIN_RENDER,
                    TRAIN_TIMESTEP = TRAIN_TIMESTEPS[0],
                    VIUSAL_INTERVAL = VIUSAL_INTERVAL,
                    VALID_SAMPLE = VALID_SAMPLE,
                    VALID_INTERVAL = VALID_INTERVAL)

# %%
class Agent:
    def __init__(self, env, net, **kwargs):
        self.env = env

        # Environment Settings
        self.mem_size = kwargs.get("MEM_SIZE")
        self.mem_size_min = kwargs.get("MEM_SIZE_MIN")

        # Learning Settings
        self.batch_size = kwargs.get("BATCH_SIZE")
        self.learning_rate = kwargs.get("LEARNING_RATE")
        self.learn_decay = kwargs.get("LEARN_DECAY")
        self.learn_min = kwargs.get("LEARN_MIN")
        self.discount = kwargs.get("DISCOUNT")

        # Exploration Settings
        self.epsilon = kwargs.get("EPSILON")
        self.epsilon_decay = kwargs.get("EPSILON_DECAY")
        self.epsilon_min = kwargs.get("EPSILON_MIN")

        # loss
        self.loss_fn = nn.MSELoss()
        self.losses = []

        # target net update
        self.target_update_counter = 0
        self.update_target_baseline = kwargs.get("UPDATE_TARGET_EVERY")

        # def model
        self.model = copy.deepcopy(net)
        self.target_model = copy.deepcopy(net)

        self.target_model.load_state_dict(self.model.state_dict())

        self.model.to(device)
        self.target_model.to(device)

        # replay memory
        self.replay_memory = deque(maxlen=self.mem_size)

    def update_target_model(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def update_replay_memory(self, transition):
        self.replay_memory.append(transition)

    def get_action(self, state):
        '''
        get_action은 하나의 state_img만을 받는다.
        '''
        if np.random.random() < self.epsilon:
            # take random action
            action = np.random.choice(range(self.env.total_tiles))

        else:
            self.model.eval()

            with torch.no_grad():
                state = torch.tensor(state.reshape(1,1,self.env.nrows,self.env.ncols),
                                     dtype=torch.float32).to(device)
                total_action = self.model(state).view(-1)
                total_action = total_action.cpu()

                self.total_action = total_action

                action = torch.argmax(total_action).item()

        return action

    def train(self, done):
        if len(self.replay_memory) < self.mem_size_min:
            return

        # optimizer
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate, eps=1e-4)

        # 리플레이 메모리에서 배치 사이즈만큼 데이터를 꺼낸다.
        # batch[i] = (current_state, action, reward, new_current_state, done)
        batch = random.sample(self.replay_memory, self.batch_size)

        # 배치 안에 저장되어 있는 정보 꺼내기
        current_states, actions, rewards, next_states, epi_dones = zip(*batch)

        current_states =  torch.tensor(np.array(current_states), dtype=torch.float32).reshape(-1,1,self.env.nrows,self.env.ncols).to(device)
        next_states = torch.tensor(np.array(next_states), dtype=torch.float32).reshape(-1,1,self.env.nrows,self.env.ncols).to(device)

        actions = torch.tensor(np.array(actions), dtype=torch.int).to(device)
        rewards = torch.tensor(np.array(rewards), dtype=torch.float).reshape(-1,1).to(device)
        epi_dones = torch.tensor(np.array(epi_dones), dtype=torch.float).reshape(-1,1).to(device)

        self.model.train()
        self.target_model.eval()

        current_q_values = self.model(current_states)

        with torch.no_grad():
            next_q_values = self.target_model(next_states)

        #     print(next_q_values.shape)
        # print(torch.max(next_q_values, dim=1)[0])
        target_value = rewards + (1 - epi_dones) * self.discount * torch.max(next_q_values, dim=1)[0].reshape(-1,1)
        target_value = target_value.flatten()

        target_q_values = copy.deepcopy(current_q_values.detach())
        target_q_values[range(BATCH_SIZE), actions] = target_value

        # print(np.sum(current_q_values.cpu().detach().numpy() != target_q_values.cpu().detach().numpy()))

        cost = self.loss_fn(current_q_values, target_q_values)

        running_loss = cost.item()
        self.losses.append(round(running_loss,6))

        self.optimizer.zero_grad()
        cost.backward()
        self.optimizer.step()

        if done:
            self.target_update_counter += 1

        if self.target_update_counter == self.update_target_baseline:
            self.update_target_model()
            self.target_update_counter = 0

        # decay learning rate
        self.learning_rate = max(self.learn_min, self.learning_rate*self.learn_decay)

        # decay epsilon
        self.epsilon = max(self.epsilon_min, self.epsilon*self.epsilon_decay)


class Limited18Agent(Agent):
    def __init__(self, env, net, replay_memory=False, **kwargs):
        super().__init__(env, net, **kwargs)
        # 불러올 리플레이 메모리가 있다면 불러옴
        if replay_memory:
            self.replay_memory = replay_memory

    def update_replay_memory(self, transition):
        current_state = transition[0]

        if np.sum(current_state != self.env.unrevealed) >= 18: # 경험적인 데이터 18(나름 하이퍼파라미터긴 함ㅋ)
            self.replay_memory.append(transition)

env = MinesweeperEnv(map_size=level['easy']['map_size'],
                     n_mines=level['easy']['n_mines'])

net = Net(input_dims=env.state.shape,
          n_actions=env.total_tiles,
          conv_units=CONV_UNITS)

agent = Limited18Agent(env=env,
                        net=net,
                        MEM_SIZE=MEM_SIZE,
                        MEM_SIZE_MIN=MEM_SIZE_MIN,
                        BATCH_SIZE=BATCH_SIZE,
                        LEARNING_RATE=LEARNING_RATE,
                        LEARN_DECAY=LEARN_DECAY,
                        LEARN_MIN=LEARN_MIN,
                        DISCOUNT=DISCOUNT,
                        EPSILON=EPSILON,
                        EPSILON_DECAY=EPSILON_DECAY,
                        EPSILON_MIN=EPSILON_MIN,
                        UPDATE_TARGET_EVERY=UPDATE_TARGET_EVERY)

trainer = Trainer(env=env,
                    agent=agent,
                    tester_agent=tester_agent,
                    name='original',
                    train_start=True,
                    EPISODES = EPISODES,
                    PRINT_INTERVAL = PRINT_INTERVAL,
                    TRAIN_RENDER = TRAIN_RENDER,
                    TRAIN_TIMESTEP = TRAIN_TIMESTEPS[0],
                    VIUSAL_INTERVAL = VIUSAL_INTERVAL,
                    VALID_SAMPLE = VALID_SAMPLE,
                    VALID_INTERVAL = VALID_INTERVAL)
