# %% [markdown]
# # 00 Init

# %% [markdown]
# ## Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Setting to use py files

# %%
import os

# %%
os.chdir('/content/drive/MyDrive/Minesweeper [RL]')

# %%
# check that os is in right directory
os.getcwd()
# Out:
# '/content/drive/MyDrive/Minesweeper [RL]'

# %%
! pip install codes
# Out:
# Collecting codes
#   Downloading codes-0.1.5-py3-none-any.whl (5.5 kB)
# Installing collected packages: codes
# Successfully installed codes-0.1.5

# %% [markdown]
# ## Import py files

# %%
# baseline : Env, Agent
from codes.Agent.DQNAgentWithoutRules import *
from codes.Trainer.trainerWithoutRules import *
from codes.Environment.env5reward import *

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# # 01 Info

# %% [markdown]
# ## level dictionary

# %%
level = {'easy' : {'map_size':(9,9), 'n_mines' : 10},
         'medium' : {'map_size':(16,16), 'n_mines':40},
         'expert' : {'map_size':(16,30), 'n_mines':99}}

# %% [markdown]
# ## HYPER PARAMETERS

# %%
# Environment settings
MEM_SIZE = 50000
MEM_SIZE_MIN = 1000

# Learning settings
BATCH_SIZE = 64
LEARNING_RATE = 0.01
LEARN_DECAY = 0.999975
LEARN_MIN = 0.001
DISCOUNT = 0.1

# Exploration settings
EPSILON = 0.95
EPSILON_DECAY = 0.99975
EPSILON_MIN = 0.01

# DQN settings
CONV_UNITS = 64
UPDATE_TARGET_EVERY = 5

# %% [markdown]
# # 02 Train, Valid

# %%
env = MinesweeperEnv(map_size=level['easy']['map_size'],
                     n_mines=level['easy']['n_mines'],
                     rewards={'win':1, 'lose':-1, 'progress':0.3, 'guess':-0.3, 'no_progress' : -1})
agent = Limited18DQNAgent(env=env, conv_units=CONV_UNITS)

# %% [markdown]
# ## TRAIN_PARAMETERS

# %%
EPISODES = 50000
PRINT_INTERVAL = 100
TRAIN_RENDER = False

TRAIN_INTERVALS = ['every timestep', 'every episodes']
TRAIN_INTERVAL = TRAIN_INTERVALS[0]

VALID_SAMPLE = 1000
VALID_INTERVAL = 10

# %%
import matplotlib.pyplot as plt
import time
import numpy as np
import pandas as pd

class Trainer:
    def __init__(self, env, agent, name):
        self.env = env
        self.agent = agent

        self.progress_list = []
        self.wins_list = []
        self.ep_rewards_list = []

        self.SIMPLE_VALID = 0
        self.name = name
        self.tester_agent = DQNAgent(env=env, conv_units=CONV_UNITS)

        self.best_model_train = None
        self.best_model_valid = None

        self.baseline_train = 0
        self.baseline_valid = 0

        start = time.time()
        self.train()
        print(round(time.time() - start, 2))

        self.visualize_train()
        self.save_model()

    def train(self):
        global VALID_SAMPLE
        win_rate = 0

        for episode in range(EPISODES):
            self.env.reset()

            n_clicks = 0
            done = False
            episode_reward = 0

            while not done:
                current_state = self.env.state

                action = self.agent.get_action(current_state)

                next_state, reward, done = self.env.step(action)

                episode_reward += reward

                self.agent.update_replay_memory((current_state, action, reward, next_state, done))

                if TRAIN_INTERVAL == TRAIN_INTERVALS[0]: # every timestep
                    self.agent.train(done)

                n_clicks += 1

            if TRAIN_INTERVAL == TRAIN_INTERVALS[1]: # every episodes
                self.agent.train(done)

            if TRAIN_RENDER:
                self.env.render(self.env.state)
                print(episode_reward)

            self.progress_list.append(n_clicks)
            self.ep_rewards_list.append(episode_reward)
            self.wins_list.append(reward == self.env.rewards['win'])

            if len(self.agent.replay_memory) < MEM_SIZE_MIN:
                continue

            if (episode+1) % PRINT_INTERVAL == 0:
                med_progress = np.median(self.progress_list[-PRINT_INTERVAL:])
                win_rate = np.sum(self.wins_list[-PRINT_INTERVAL:]) / PRINT_INTERVAL
                med_reward = np.median(self.ep_rewards_list[-PRINT_INTERVAL:])

                print(f"Episode: [{EPISODES}/{episode+1}], Median progress: {med_progress:.2f}, Median reward: {med_reward:.2f}, Win rate : {win_rate:.2f}, Epsilon: {self.agent.epsilon:.2f}")

                if win_rate > self.baseline_train:
                    self.baseline_train = win_rate
                    self.best_model_train = self.agent.model.state_dict()

                    self.SIMPLE_VALID = 10

            if self.SIMPLE_VALID > 0:
                    valid_state = self.agent.model.state_dict()
                    valid_win_rate = self.valid_model(self.env, self.tester_agent, episode, VALID_SAMPLE, valid_state)
                    self.SIMPLE_VALID -= 1

            if win_rate > self.baseline_valid:
                self.baseline_valid = valid_win_rate
                self.best_model_valid = self.agent.model.state_dict()

    def valid_model(self, env, agent, episode, epoch, model_state):

        progress_list, wins_list, ep_rewards = [], [], []

        agent.epsilon = 0.0 # valid에서는 탐험을 꺼준다.

        agent.model.load_state_dict(model_state)
        agent.target_model.load_state_dict(model_state)

        for i in range(epoch):
            # print(f"{episode} : {i}")
            env.reset()
            # print(1)

            done = False
            n_clicks = 0
            episode_reward = 0

            # print(2)
            while not done:
                current_state = env.state
                # print("current")
                # env.render(current_state)

                action = agent.get_action(current_state)
                # print(action)
                next_state, reward, done = env.step(action)
                # print("next_state")
                # print(reward)
                # env.render(next_state)
                # print(done)

                episode_reward += reward
                n_clicks += 1

            progress_list.append(n_clicks)
            ep_rewards.append(episode_reward)

            if reward == env.rewards['win']:
                wins_list.append(1)
            else:
                wins_list.append(0)

        print(f"Valid n:{epoch}, Median progress: {np.median(progress_list):.2f}, Median reward: {np.median(ep_rewards):.2f}, Win rate : {np.sum(wins_list)/len(wins_list)}")

        return np.sum(wins_list)/len(wins_list) # 승률을 반환한다.

    def visualize_train(self, progress=True, win_rates=True, rewards=True, losses=True):
        progresses = []
        win_rates = []
        rewards = []
        losses = []

        INTERVAL = 100

        for start in range(0, len(self.progress_list)-INTERVAL, INTERVAL):
            progresses.append(sum(self.progress_list[start:start+INTERVAL]) / INTERVAL)
            win_rates.append(sum(self.wins_list[start:start+INTERVAL]) / INTERVAL)
            rewards.append(sum(self.ep_rewards_list[start:start+INTERVAL]) / INTERVAL)
            losses.append(sum(self.agent.losses[start:start+INTERVAL]) / INTERVAL)

        interval = 500
        xticks = np.arange(0, len(self.progress_list), interval)

        if progress:
            if len(progresses) > 50:
                plt.xticks(xticks, [str(x) + 'K' for x in xticks // 10])
            plt.axhline(y=(sum(self.progress_list)/len(self.progress_list)), color='b', linestyle='-')
            plt.scatter(range(len(progresses)), progresses, marker='.',alpha=0.3,
                        color=['red' if x == max(progresses) else 'black' for x in progresses])
            plt.annotate(max(progresses), (progresses.index(max(progresses))+5, max(progresses)))
            plt.title(f"Median Progress per {INTERVAL} episodes")
            plt.show()

        if win_rates:
            if len(progresses) > 50:
                plt.xticks(xticks, [str(x) + 'K' for x in xticks // 10])
                plt.axhline(y=(sum(self.wins_list)/len(self.wins_list)), color='b', linestyle='-')
                plt.axhline(y=(sum(self.wins_list[-100:])/len(self.wins_list[-100:])), color='b', linestyle='--')
            plt.fill_between(range(len(win_rates)), min(win_rates), win_rates, alpha=0.7)
            plt.scatter(win_rates.index(max(win_rates)), max(win_rates), marker='.', color='r')
            plt.annotate(max(win_rates), (win_rates.index(max(win_rates))+5, max(win_rates)))
            plt.title(f"Median Win rate per {INTERVAL} episodes")
            plt.show()

        if rewards:
            if len(progresses) > 50:
                plt.xticks(xticks, [str(x) + 'K' for x in xticks // 10])
                plt.axhline(y=(sum(self.ep_rewards_list)/len(self.ep_rewards_list)), color='b', linestyle='-')
            plt.scatter(range(len(rewards)), rewards,
                        marker='.', alpha=0.3, color=['red' if x == max(rewards) else 'black' for x in rewards])
            plt.annotate(round(max(rewards),2), (rewards.index(max(rewards))+5, max(rewards)))
            plt.title(f"Median Episode Reward per {INTERVAL} episodes")
            plt.show()

        if losses:
            if len(progresses) > 50:
                plt.xticks(xticks, [str(x) + 'K' for x in xticks // 10])
            plt.plot(losses)
            plt.title(f"Median Loss per {INTERVAL} episodes")
            plt.show()

    def save_model(self):

        def save_file(direction, fname, file):
           with open(os.path.join(direction, f'{fname}.pkl'), 'wb') as f:
                pickle.dump(file,f)

        def create_file(path, name):
            file_path = path + '/' + name
            # 파일이 이미 존재하는지 확인
            if not os.path.exists(file_path):
                os.makedirs(file_path)
                print(f"파일 '{file_path}'가 생성되었습니다.")
            else:
                print(f"파일 '{file_path}'는 이미 존재합니다.")

        save_point = {}
        save_point['n_mines'] = self.env.total_mines
        save_point['total_episodes'] = len(self.progress_list)
        save_point['final_model'] = self.agent.model.state_dict()
        save_point['best_model_train'] = self.best_model_train
        save_point['best_model_valid'] = self.best_model_valid

        self.save_point = save_point

        f_path = '/content/drive/MyDrive/Minesweeper [RL]/models'
        name = self.name

        create_file(f_path, name)
        save_file(f_path + '/' + name, f'{len(self.progress_list)}epi_max_train{self.baseline_train}_valid{self.baseline_valid}',save_point)
        print('모델이 저장되었습니다.')

# %%
train = Trainer(env, agent, 'basicModelWithoutBiasRuleDone_1')
# Out:
# Episode: [50000/900], Median progress: 4.00, Median reward: -1.35, Win rate : 0.00, Epsilon: 0.87
# Episode: [50000/1000], Median progress: 3.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.79
# Episode: [50000/1100], Median progress: 3.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.72
# Episode: [50000/1200], Median progress: 3.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.66
# Episode: [50000/1300], Median progress: 4.00, Median reward: -1.30, Win rate : 0.00, Epsilon: 0.60
# Episode: [50000/1400], Median progress: 3.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.54
# Episode: [50000/1500], Median progress: 3.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.49
# Episode: [50000/1600], Median progress: 4.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.45
# Episode: [50000/1700], Median progress: 3.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.41
# Episode: [50000/1800], Median progress: 3.00, Median reward: -1.30, Win rate : 0.00, Epsilon: 0.37
# Episode: [50000/1900], Median progress: 3.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.34
# Episode: [50000/2000], Median progress: 3.00, Median reward: -0.80, Win rate : 0.00, Epsilon: 0.31
# Episode: [50000/2100], Median progress: 3.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.28
# Episode: [50000/2200], Median progress: 3.00, Median reward: -0.80, Win rate : 0.00, Epsilon: 0.26
# Episode: [50000/2300], Median progress: 4.00, Median reward: -1.00, Win rate : 0.00, Epsilon: 0.23
# Episode: [50000/2400], Median progress: 3.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.21
# Episode: [50000/2500], Median progress: 4.00, Median reward: -1.30, Win rate : 0.00, Epsilon: 0.19
# Episode: [50000/2600], Median progress: 4.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.17
# Episode: [50000/2700], Median progress: 4.00, Median reward: -1.30, Win rate : 0.00, Epsilon: 0.15
# Episode: [50000/2800], Median progress: 3.50, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.14
# Episode: [50000/2900], Median progress: 4.00, Median reward: -1.00, Win rate : 0.00, Epsilon: 0.12
# Episode: [50000/3000], Median progress: 4.00, Median reward: -1.10, Win rate : 0.00, Epsilon: 0.11
# Episode: [50000/3100], Median progress: 4.00, Median reward: -1.00, Win rate : 0.00, Epsilon: 0.10
# Episode: [50000/3200], Median progress: 4.00, Median reward: -0.80, Win rate : 0.00, Epsilon: 0.09
# Episode: [50000/3300], Median progress: 4.00, Median reward: -0.80, Win rate : 0.00, Epsilon: 0.08
# Episode: [50000/3400], Median progress: 4.00, Median reward: -0.80, Win rate : 0.00, Epsilon: 0.07
# Episode: [50000/3500], Median progress: 4.00, Median reward: -0.80, Win rate : 0.00, Epsilon: 0.06
# Episode: [50000/3600], Median progress: 4.00, Median reward: -0.70, Win rate : 0.00, Epsilon: 0.06
# Episode: [50000/3700], Median progress: 4.00, Median reward: -0.50, Win rate : 0.00, Epsilon: 0.05
# Episode: [50000/3800], Median progress: 4.00, Median reward: -0.80, Win rate : 0.00, Epsilon: 0.04
# Episode: [50000/3900], Median progress: 4.00, Median reward: -0.70, Win rate : 0.00, Epsilon: 0.04
# Episode: [50000/4000], Median progress: 4.00, Median reward: -0.70, Win rate : 0.00, Epsilon: 0.03
# Episode: [50000/4100], Median progress: 4.00, Median reward: -0.70, Win rate : 0.00, Epsilon: 0.03
# Episode: [50000/4200], Median progress: 4.00, Median reward: -0.50, Win rate : 0.00, Epsilon: 0.03
# Episode: [50000/4300], Median progress: 5.00, Median reward: -0.50, Win rate : 0.00, Epsilon: 0.02
# Episode: [50000/4400], Median progress: 5.00, Median reward: -0.50, Win rate : 0.00, Epsilon: 0.02
# Episode: [50000/4500], Median progress: 5.00, Median reward: -0.50, Win rate : 0.00, Epsilon: 0.02
# Episode: [50000/4600], Median progress: 5.00, Median reward: -0.45, Win rate : 0.00, Epsilon: 0.02
# Episode: [50000/4700], Median progress: 4.00, Median reward: -0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/4800], Median progress: 4.00, Median reward: -0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/4900], Median progress: 4.00, Median reward: -0.60, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/5000], Median progress: 4.00, Median reward: -0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/5100], Median progress: 5.00, Median reward: -0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/5200], Median progress: 5.00, Median reward: -0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/5300], Median progress: 5.00, Median reward: -0.60, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/5400], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/5500], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/5600], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/5700], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/5800], Median progress: 5.00, Median reward: -0.30, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/5900], Median progress: 4.00, Median reward: -0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/6000], Median progress: 5.00, Median reward: -0.30, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/6100], Median progress: 4.00, Median reward: -0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/6200], Median progress: 5.00, Median reward: -0.45, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/6300], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/6400], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/6500], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/6600], Median progress: 5.00, Median reward: -0.45, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/6700], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/6800], Median progress: 4.00, Median reward: -0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/6900], Median progress: 4.00, Median reward: -0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/7000], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/7100], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/7200], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/7300], Median progress: 5.50, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/7400], Median progress: 6.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/7500], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/7600], Median progress: 6.00, Median reward: -0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/7700], Median progress: 6.00, Median reward: -0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/7800], Median progress: 5.00, Median reward: -0.10, Win rate : 0.01, Epsilon: 0.01
# Valid n:1000, Median progress: 5.00, Median reward: -0.40, Win rate : 0.0
# Valid n:1000, Median progress: 5.00, Median reward: -0.40, Win rate : 0.0
# Valid n:1000, Median progress: 5.00, Median reward: -0.40, Win rate : 0.0
# Valid n:1000, Median progress: 5.00, Median reward: -0.20, Win rate : 0.001
# Valid n:1000, Median progress: 5.00, Median reward: -0.40, Win rate : 0.0
# Valid n:1000, Median progress: 5.00, Median reward: -0.40, Win rate : 0.0
# Valid n:1000, Median progress: 5.00, Median reward: -0.40, Win rate : 0.0
# Valid n:1000, Median progress: 5.00, Median reward: -0.40, Win rate : 0.001
# Valid n:1000, Median progress: 5.00, Median reward: -0.20, Win rate : 0.001
# Valid n:1000, Median progress: 5.00, Median reward: -0.20, Win rate : 0.0
# Episode: [50000/7900], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/8000], Median progress: 5.00, Median reward: -0.30, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/8100], Median progress: 5.00, Median reward: -0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/8200], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/8300], Median progress: 6.00, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/8400], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/8500], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/8600], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/8700], Median progress: 5.00, Median reward: -0.10, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/8800], Median progress: 5.50, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/8900], Median progress: 5.00, Median reward: -0.30, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/9000], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/9100], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/9200], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/9300], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/9400], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/9500], Median progress: 5.00, Median reward: -0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/9600], Median progress: 4.00, Median reward: -0.45, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/9700], Median progress: 5.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/9800], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/9900], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/10000], Median progress: 6.00, Median reward: -0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/10100], Median progress: 5.00, Median reward: -0.30, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/10200], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/10300], Median progress: 6.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/10400], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/10500], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/10600], Median progress: 6.00, Median reward: -0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/10700], Median progress: 6.00, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/10800], Median progress: 7.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/10900], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/11000], Median progress: 6.50, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/11100], Median progress: 5.00, Median reward: -0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/11200], Median progress: 6.00, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/11300], Median progress: 6.00, Median reward: -0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/11400], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/11500], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/11600], Median progress: 6.00, Median reward: -0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/11700], Median progress: 6.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/11800], Median progress: 6.00, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/11900], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/12000], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/12100], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/12200], Median progress: 6.00, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/12300], Median progress: 6.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/12400], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/12500], Median progress: 6.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/12600], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/12700], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/12800], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/12900], Median progress: 7.00, Median reward: 0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/13000], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/13100], Median progress: 6.00, Median reward: -0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/13200], Median progress: 6.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/13300], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/13400], Median progress: 7.00, Median reward: 0.10, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/13500], Median progress: 5.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/13600], Median progress: 6.00, Median reward: -0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/13700], Median progress: 5.50, Median reward: -0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/13800], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/13900], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/14000], Median progress: 7.00, Median reward: 0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/14100], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/14200], Median progress: 7.00, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/14300], Median progress: 6.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/14400], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/14500], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/14600], Median progress: 6.00, Median reward: -0.10, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/14700], Median progress: 6.50, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/14800], Median progress: 6.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/14900], Median progress: 7.00, Median reward: 0.20, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/15000], Median progress: 7.00, Median reward: 0.30, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/15100], Median progress: 6.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/15200], Median progress: 7.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/15300], Median progress: 5.50, Median reward: -0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/15400], Median progress: 6.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/15500], Median progress: 7.00, Median reward: 0.30, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/15600], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/15700], Median progress: 7.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/15800], Median progress: 6.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/15900], Median progress: 6.50, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/16000], Median progress: 6.00, Median reward: -0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/16100], Median progress: 7.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/16200], Median progress: 7.00, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/16300], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/16400], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/16500], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/16600], Median progress: 6.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/16700], Median progress: 7.00, Median reward: 0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/16800], Median progress: 7.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/16900], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/17000], Median progress: 6.00, Median reward: -0.10, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/17100], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/17200], Median progress: 7.00, Median reward: 0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/17300], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/17400], Median progress: 7.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/17500], Median progress: 6.00, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/17600], Median progress: 6.50, Median reward: 0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/17700], Median progress: 8.00, Median reward: 0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/17800], Median progress: 6.50, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/17900], Median progress: 6.00, Median reward: -0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/18000], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/18100], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/18200], Median progress: 6.50, Median reward: -0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/18300], Median progress: 7.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/18400], Median progress: 7.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/18500], Median progress: 7.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/18600], Median progress: 7.00, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/18700], Median progress: 7.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/18800], Median progress: 6.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/18900], Median progress: 6.00, Median reward: -0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/19000], Median progress: 6.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/19100], Median progress: 6.00, Median reward: -0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/19200], Median progress: 7.00, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/19300], Median progress: 7.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/19400], Median progress: 6.50, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/19500], Median progress: 7.00, Median reward: 0.10, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/19600], Median progress: 7.50, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/19700], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/19800], Median progress: 7.00, Median reward: -0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/19900], Median progress: 7.50, Median reward: 0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/20000], Median progress: 6.00, Median reward: 0.30, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/20100], Median progress: 7.00, Median reward: 0.20, Win rate : 0.02, Epsilon: 0.01
# Valid n:1000, Median progress: 7.00, Median reward: 0.20, Win rate : 0.001
# Valid n:1000, Median progress: 7.00, Median reward: 0.20, Win rate : 0.001
# Valid n:1000, Median progress: 7.00, Median reward: 0.20, Win rate : 0.002
# Valid n:1000, Median progress: 7.00, Median reward: 0.20, Win rate : 0.0
# Valid n:1000, Median progress: 7.00, Median reward: 0.20, Win rate : 0.0
# Valid n:1000, Median progress: 7.00, Median reward: 0.40, Win rate : 0.001
# Valid n:1000, Median progress: 7.00, Median reward: 0.40, Win rate : 0.001
# Valid n:1000, Median progress: 7.00, Median reward: 0.20, Win rate : 0.001
# Valid n:1000, Median progress: 7.00, Median reward: 0.20, Win rate : 0.003
# Valid n:1000, Median progress: 7.00, Median reward: 0.20, Win rate : 0.002
# Episode: [50000/20200], Median progress: 8.00, Median reward: 0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/20300], Median progress: 6.50, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/20400], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/20500], Median progress: 7.00, Median reward: 0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/20600], Median progress: 7.00, Median reward: 0.40, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/20700], Median progress: 6.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/20800], Median progress: 7.00, Median reward: 0.30, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/20900], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/21000], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/21100], Median progress: 6.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/21200], Median progress: 6.50, Median reward: 0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/21300], Median progress: 8.00, Median reward: 0.20, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/21400], Median progress: 8.00, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/21500], Median progress: 8.00, Median reward: 0.45, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/21600], Median progress: 7.00, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/21700], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/21800], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/21900], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/22000], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/22100], Median progress: 8.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/22200], Median progress: 7.00, Median reward: -0.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/22300], Median progress: 8.00, Median reward: 0.60, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/22400], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/22500], Median progress: 7.00, Median reward: -0.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/22600], Median progress: 8.00, Median reward: 0.30, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/22700], Median progress: 7.50, Median reward: 0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/22800], Median progress: 8.00, Median reward: 0.10, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/22900], Median progress: 7.00, Median reward: 0.15, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/23000], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/23100], Median progress: 9.00, Median reward: 0.80, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/23200], Median progress: 7.00, Median reward: 0.20, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/23300], Median progress: 9.00, Median reward: 0.75, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/23400], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/23500], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/23600], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/23700], Median progress: 9.00, Median reward: 0.80, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/23800], Median progress: 7.00, Median reward: 0.40, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/23900], Median progress: 7.00, Median reward: 0.30, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/24000], Median progress: 8.00, Median reward: 0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/24100], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/24200], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/24300], Median progress: 9.00, Median reward: 1.00, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/24400], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/24500], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/24600], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/24700], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/24800], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/24900], Median progress: 8.00, Median reward: 0.45, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/25000], Median progress: 6.00, Median reward: 0.15, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/25100], Median progress: 8.00, Median reward: 0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/25200], Median progress: 7.00, Median reward: 0.45, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/25300], Median progress: 8.00, Median reward: 0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/25400], Median progress: 9.00, Median reward: 0.75, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/25500], Median progress: 9.00, Median reward: 0.80, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/25600], Median progress: 9.00, Median reward: 0.75, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/25700], Median progress: 8.00, Median reward: 0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/25800], Median progress: 8.00, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/25900], Median progress: 8.00, Median reward: 0.30, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/26000], Median progress: 8.00, Median reward: 0.80, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/26100], Median progress: 7.00, Median reward: 0.20, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/26200], Median progress: 9.00, Median reward: 0.80, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/26300], Median progress: 7.00, Median reward: 0.20, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/26400], Median progress: 9.00, Median reward: 1.00, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/26500], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/26600], Median progress: 8.00, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/26700], Median progress: 9.00, Median reward: 0.80, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/26800], Median progress: 8.00, Median reward: 0.50, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/26900], Median progress: 8.00, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/27000], Median progress: 8.00, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/27100], Median progress: 7.50, Median reward: 0.35, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/27200], Median progress: 9.00, Median reward: 0.70, Win rate : 0.03, Epsilon: 0.01
# Valid n:1000, Median progress: 8.00, Median reward: 0.70, Win rate : 0.005
# Valid n:1000, Median progress: 8.00, Median reward: 0.70, Win rate : 0.005
# Valid n:1000, Median progress: 9.00, Median reward: 0.90, Win rate : 0.007
# Valid n:1000, Median progress: 8.00, Median reward: 0.50, Win rate : 0.007
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.009
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.009
# Valid n:1000, Median progress: 8.00, Median reward: 0.70, Win rate : 0.007
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.004
# Valid n:1000, Median progress: 8.00, Median reward: 0.70, Win rate : 0.01
# Valid n:1000, Median progress: 8.00, Median reward: 0.50, Win rate : 0.004
# Episode: [50000/27300], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/27400], Median progress: 8.00, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/27500], Median progress: 7.50, Median reward: 0.45, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/27600], Median progress: 8.00, Median reward: 0.60, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/27700], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/27800], Median progress: 8.00, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/27900], Median progress: 9.00, Median reward: 0.90, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/28000], Median progress: 9.00, Median reward: 0.80, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/28100], Median progress: 7.00, Median reward: 0.45, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/28200], Median progress: 9.00, Median reward: 0.80, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/28300], Median progress: 9.00, Median reward: 0.70, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/28400], Median progress: 9.50, Median reward: 1.00, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/28500], Median progress: 7.00, Median reward: 0.20, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/28600], Median progress: 7.00, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/28700], Median progress: 8.50, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/28800], Median progress: 10.00, Median reward: 1.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/28900], Median progress: 8.00, Median reward: 0.60, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/29000], Median progress: 7.50, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/29100], Median progress: 8.00, Median reward: 0.50, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/29200], Median progress: 9.00, Median reward: 0.80, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/29300], Median progress: 8.00, Median reward: 0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/29400], Median progress: 8.00, Median reward: 0.80, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/29500], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/29600], Median progress: 8.00, Median reward: 0.50, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/29700], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/29800], Median progress: 9.00, Median reward: 0.80, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/29900], Median progress: 9.00, Median reward: 0.80, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/30000], Median progress: 7.00, Median reward: 0.20, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/30100], Median progress: 9.00, Median reward: 0.70, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/30200], Median progress: 8.00, Median reward: 0.45, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/30300], Median progress: 9.00, Median reward: 0.80, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/30400], Median progress: 8.00, Median reward: 0.30, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/30500], Median progress: 9.50, Median reward: 0.90, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/30600], Median progress: 9.00, Median reward: 0.75, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/30700], Median progress: 8.00, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/30800], Median progress: 6.50, Median reward: 0.30, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/30900], Median progress: 8.00, Median reward: 0.40, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/31000], Median progress: 8.00, Median reward: 0.20, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/31100], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/31200], Median progress: 8.00, Median reward: 0.45, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/31300], Median progress: 9.00, Median reward: 0.80, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/31400], Median progress: 8.00, Median reward: 0.45, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/31500], Median progress: 8.50, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/31600], Median progress: 7.00, Median reward: 0.45, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/31700], Median progress: 8.50, Median reward: 0.80, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/31800], Median progress: 8.00, Median reward: 0.50, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/31900], Median progress: 6.50, Median reward: 0.15, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/32000], Median progress: 9.50, Median reward: 1.00, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/32100], Median progress: 7.00, Median reward: 0.30, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/32200], Median progress: 8.00, Median reward: 0.70, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/32300], Median progress: 8.50, Median reward: 0.75, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/32400], Median progress: 8.00, Median reward: 0.70, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/32500], Median progress: 8.50, Median reward: 0.80, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/32600], Median progress: 8.00, Median reward: 0.50, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/32700], Median progress: 9.00, Median reward: 1.05, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/32800], Median progress: 8.00, Median reward: 0.75, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/32900], Median progress: 8.00, Median reward: 0.75, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/33000], Median progress: 8.00, Median reward: 0.50, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/33100], Median progress: 7.00, Median reward: 0.20, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/33200], Median progress: 8.00, Median reward: 0.50, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/33300], Median progress: 10.00, Median reward: 1.05, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/33400], Median progress: 8.00, Median reward: 0.50, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/33500], Median progress: 9.00, Median reward: 0.75, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/33600], Median progress: 8.00, Median reward: 0.80, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/33700], Median progress: 9.00, Median reward: 0.80, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/33800], Median progress: 8.00, Median reward: 0.70, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/33900], Median progress: 9.50, Median reward: 1.10, Win rate : 0.04, Epsilon: 0.01
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.019
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.014
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.016
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.013
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.01
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.02
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.011
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.012
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.021
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.015
# Episode: [50000/34000], Median progress: 9.00, Median reward: 0.70, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/34100], Median progress: 8.00, Median reward: 0.60, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/34200], Median progress: 8.00, Median reward: 0.80, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/34300], Median progress: 8.00, Median reward: 0.50, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/34400], Median progress: 6.00, Median reward: -0.10, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/34500], Median progress: 10.00, Median reward: 1.10, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/34600], Median progress: 9.00, Median reward: 0.90, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/34700], Median progress: 9.00, Median reward: 0.90, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/34800], Median progress: 10.00, Median reward: 1.10, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/34900], Median progress: 10.00, Median reward: 1.20, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/35000], Median progress: 10.00, Median reward: 1.10, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/35100], Median progress: 8.00, Median reward: 0.50, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/35200], Median progress: 9.50, Median reward: 1.10, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/35300], Median progress: 9.00, Median reward: 1.00, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/35400], Median progress: 9.00, Median reward: 1.00, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/35500], Median progress: 10.00, Median reward: 1.05, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/35600], Median progress: 10.50, Median reward: 1.40, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/35700], Median progress: 9.50, Median reward: 1.20, Win rate : 0.05, Epsilon: 0.01
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.018
# Valid n:1000, Median progress: 9.00, Median reward: 1.10, Win rate : 0.023
# Valid n:1000, Median progress: 9.00, Median reward: 1.10, Win rate : 0.031
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.023
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.021
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.023
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.026
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.027
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.028
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.015
# Episode: [50000/35800], Median progress: 11.00, Median reward: 1.75, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/35900], Median progress: 8.00, Median reward: 0.80, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/36000], Median progress: 9.00, Median reward: 1.05, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/36100], Median progress: 9.00, Median reward: 0.80, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/36200], Median progress: 9.00, Median reward: 0.60, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/36300], Median progress: 8.00, Median reward: 0.30, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/36400], Median progress: 8.00, Median reward: 0.50, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/36500], Median progress: 11.00, Median reward: 1.30, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/36600], Median progress: 9.00, Median reward: 1.10, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/36700], Median progress: 8.50, Median reward: 0.75, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/36800], Median progress: 11.00, Median reward: 1.50, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/36900], Median progress: 9.00, Median reward: 1.00, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/37000], Median progress: 11.00, Median reward: 1.40, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/37100], Median progress: 8.00, Median reward: 0.40, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/37200], Median progress: 10.00, Median reward: 1.10, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/37300], Median progress: 7.00, Median reward: 0.20, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/37400], Median progress: 9.00, Median reward: 1.00, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/37500], Median progress: 8.50, Median reward: 0.70, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/37600], Median progress: 8.00, Median reward: 0.50, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/37700], Median progress: 8.50, Median reward: 1.00, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/37800], Median progress: 10.00, Median reward: 1.10, Win rate : 0.00, Epsilon: 0.01
# Episode: [50000/37900], Median progress: 10.00, Median reward: 1.35, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/38000], Median progress: 8.00, Median reward: 0.55, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/38100], Median progress: 8.00, Median reward: 0.70, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/38200], Median progress: 10.00, Median reward: 1.35, Win rate : 0.07, Epsilon: 0.01
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.029
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.023
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.024
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.02
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.033
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.038
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.031
# Valid n:1000, Median progress: 10.00, Median reward: 1.30, Win rate : 0.023
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.04
# Valid n:1000, Median progress: 9.00, Median reward: 1.00, Win rate : 0.033
# Episode: [50000/38300], Median progress: 10.00, Median reward: 1.10, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/38400], Median progress: 9.00, Median reward: 1.30, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/38500], Median progress: 9.50, Median reward: 0.95, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/38600], Median progress: 10.50, Median reward: 1.50, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/38700], Median progress: 9.00, Median reward: 1.00, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/38800], Median progress: 8.50, Median reward: 0.70, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/38900], Median progress: 9.00, Median reward: 0.60, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/39000], Median progress: 9.00, Median reward: 0.90, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/39100], Median progress: 9.00, Median reward: 1.00, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/39200], Median progress: 10.00, Median reward: 1.10, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/39300], Median progress: 9.00, Median reward: 1.00, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/39400], Median progress: 9.00, Median reward: 0.75, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/39500], Median progress: 10.00, Median reward: 1.20, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/39600], Median progress: 10.50, Median reward: 1.35, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/39700], Median progress: 10.00, Median reward: 1.50, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/39800], Median progress: 11.00, Median reward: 1.50, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/39900], Median progress: 11.00, Median reward: 1.40, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/40000], Median progress: 10.00, Median reward: 1.60, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/40100], Median progress: 9.00, Median reward: 0.90, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/40200], Median progress: 11.00, Median reward: 1.40, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/40300], Median progress: 11.50, Median reward: 1.80, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/40400], Median progress: 9.50, Median reward: 0.95, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/40500], Median progress: 11.00, Median reward: 1.40, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/40600], Median progress: 10.00, Median reward: 1.30, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/40700], Median progress: 9.00, Median reward: 0.90, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/40800], Median progress: 11.00, Median reward: 1.40, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/40900], Median progress: 11.00, Median reward: 1.65, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/41000], Median progress: 10.00, Median reward: 1.35, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/41100], Median progress: 9.50, Median reward: 1.30, Win rate : 0.08, Epsilon: 0.01
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.048
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.044
# Valid n:1000, Median progress: 9.00, Median reward: 0.90, Win rate : 0.043
# Valid n:1000, Median progress: 10.00, Median reward: 1.00, Win rate : 0.049
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.064
# Valid n:1000, Median progress: 9.00, Median reward: 1.00, Win rate : 0.044
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.051
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.05
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.048
# Valid n:1000, Median progress: 9.00, Median reward: 0.80, Win rate : 0.044
# Episode: [50000/41200], Median progress: 9.00, Median reward: 0.90, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/41300], Median progress: 10.00, Median reward: 1.10, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/41400], Median progress: 10.00, Median reward: 1.20, Win rate : 0.08, Epsilon: 0.01
# Episode: [50000/41500], Median progress: 10.00, Median reward: 1.20, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/41600], Median progress: 9.00, Median reward: 0.80, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/41700], Median progress: 10.00, Median reward: 1.30, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/41800], Median progress: 11.00, Median reward: 1.35, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/41900], Median progress: 9.00, Median reward: 1.00, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/42000], Median progress: 10.00, Median reward: 1.10, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/42100], Median progress: 9.00, Median reward: 1.00, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/42200], Median progress: 9.00, Median reward: 1.20, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/42300], Median progress: 11.00, Median reward: 1.30, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/42400], Median progress: 9.50, Median reward: 1.30, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/42500], Median progress: 10.00, Median reward: 1.10, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/42600], Median progress: 11.00, Median reward: 1.40, Win rate : 0.02, Epsilon: 0.01
# Episode: [50000/42700], Median progress: 11.00, Median reward: 1.40, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/42800], Median progress: 9.00, Median reward: 1.00, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/42900], Median progress: 9.00, Median reward: 0.80, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/43000], Median progress: 10.00, Median reward: 1.30, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/43100], Median progress: 11.00, Median reward: 1.30, Win rate : 0.07, Epsilon: 0.01
# Episode: [50000/43200], Median progress: 9.00, Median reward: 1.00, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/43300], Median progress: 11.00, Median reward: 1.10, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/43400], Median progress: 9.50, Median reward: 1.10, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/43500], Median progress: 10.00, Median reward: 1.20, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/43600], Median progress: 10.00, Median reward: 1.20, Win rate : 0.08, Epsilon: 0.01
# Episode: [50000/43700], Median progress: 10.00, Median reward: 1.05, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/43800], Median progress: 10.00, Median reward: 1.05, Win rate : 0.07, Epsilon: 0.01
# Episode: [50000/43900], Median progress: 12.00, Median reward: 2.00, Win rate : 0.03, Epsilon: 0.01
# Episode: [50000/44000], Median progress: 10.00, Median reward: 1.10, Win rate : 0.07, Epsilon: 0.01
# Episode: [50000/44100], Median progress: 10.00, Median reward: 1.30, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/44200], Median progress: 10.00, Median reward: 1.20, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/44300], Median progress: 11.00, Median reward: 1.40, Win rate : 0.09, Epsilon: 0.01
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.088
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.088
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.085
# Valid n:1000, Median progress: 11.00, Median reward: 1.30, Win rate : 0.08
# Valid n:1000, Median progress: 10.00, Median reward: 1.30, Win rate : 0.076
# Valid n:1000, Median progress: 10.00, Median reward: 1.30, Win rate : 0.083
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.086
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.097
# Valid n:1000, Median progress: 10.00, Median reward: 1.30, Win rate : 0.097
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.083
# Episode: [50000/44400], Median progress: 10.00, Median reward: 1.10, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/44500], Median progress: 10.00, Median reward: 1.10, Win rate : 0.01, Epsilon: 0.01
# Episode: [50000/44600], Median progress: 11.00, Median reward: 1.50, Win rate : 0.13, Epsilon: 0.01
# Valid n:1000, Median progress: 10.00, Median reward: 1.30, Win rate : 0.099
# Valid n:1000, Median progress: 10.00, Median reward: 1.30, Win rate : 0.079
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.097
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.069
# Valid n:1000, Median progress: 10.00, Median reward: 1.40, Win rate : 0.093
# Valid n:1000, Median progress: 10.00, Median reward: 1.35, Win rate : 0.1
# Valid n:1000, Median progress: 10.00, Median reward: 1.30, Win rate : 0.08
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.095
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.094
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.1
# Episode: [50000/44700], Median progress: 10.00, Median reward: 1.20, Win rate : 0.04, Epsilon: 0.01
# Episode: [50000/44800], Median progress: 12.00, Median reward: 1.70, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/44900], Median progress: 10.00, Median reward: 1.40, Win rate : 0.08, Epsilon: 0.01
# Episode: [50000/45000], Median progress: 9.00, Median reward: 1.20, Win rate : 0.07, Epsilon: 0.01
# Episode: [50000/45100], Median progress: 11.00, Median reward: 1.70, Win rate : 0.08, Epsilon: 0.01
# Episode: [50000/45200], Median progress: 11.00, Median reward: 1.25, Win rate : 0.08, Epsilon: 0.01
# Episode: [50000/45300], Median progress: 10.50, Median reward: 1.40, Win rate : 0.15, Epsilon: 0.01
# Valid n:1000, Median progress: 10.00, Median reward: 1.30, Win rate : 0.089
# Valid n:1000, Median progress: 10.00, Median reward: 1.30, Win rate : 0.083
# Valid n:1000, Median progress: 10.00, Median reward: 1.10, Win rate : 0.08
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.101
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.111
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.075
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.103
# Valid n:1000, Median progress: 11.00, Median reward: 1.40, Win rate : 0.109
# Valid n:1000, Median progress: 11.00, Median reward: 1.50, Win rate : 0.108
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.096
# Episode: [50000/45400], Median progress: 9.00, Median reward: 0.80, Win rate : 0.05, Epsilon: 0.01
# Episode: [50000/45500], Median progress: 12.00, Median reward: 1.70, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/45600], Median progress: 12.00, Median reward: 1.90, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/45700], Median progress: 10.00, Median reward: 0.95, Win rate : 0.07, Epsilon: 0.01
# Episode: [50000/45800], Median progress: 10.00, Median reward: 1.05, Win rate : 0.06, Epsilon: 0.01
# Episode: [50000/45900], Median progress: 9.00, Median reward: 0.90, Win rate : 0.07, Epsilon: 0.01
# Episode: [50000/46000], Median progress: 9.00, Median reward: 1.10, Win rate : 0.12, Epsilon: 0.01
# Episode: [50000/46100], Median progress: 11.00, Median reward: 1.60, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/46200], Median progress: 10.00, Median reward: 1.35, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/46300], Median progress: 10.00, Median reward: 1.10, Win rate : 0.08, Epsilon: 0.01
# Episode: [50000/46400], Median progress: 11.50, Median reward: 1.70, Win rate : 0.12, Epsilon: 0.01
# Episode: [50000/46500], Median progress: 10.00, Median reward: 1.10, Win rate : 0.10, Epsilon: 0.01
# Episode: [50000/46600], Median progress: 13.00, Median reward: 2.25, Win rate : 0.14, Epsilon: 0.01
# Episode: [50000/46700], Median progress: 12.00, Median reward: 1.70, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/46800], Median progress: 10.00, Median reward: 1.30, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/46900], Median progress: 11.50, Median reward: 1.40, Win rate : 0.15, Epsilon: 0.01
# Episode: [50000/47000], Median progress: 10.00, Median reward: 1.50, Win rate : 0.16, Epsilon: 0.01
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.145
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.131
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.137
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.145
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.133
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.131
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.142
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.134
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.135
# Valid n:1000, Median progress: 12.00, Median reward: 1.90, Win rate : 0.128
# Episode: [50000/47100], Median progress: 10.00, Median reward: 1.30, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/47200], Median progress: 10.50, Median reward: 1.40, Win rate : 0.10, Epsilon: 0.01
# Episode: [50000/47300], Median progress: 9.00, Median reward: 1.05, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/47400], Median progress: 12.00, Median reward: 1.80, Win rate : 0.08, Epsilon: 0.01
# Episode: [50000/47500], Median progress: 12.00, Median reward: 1.70, Win rate : 0.08, Epsilon: 0.01
# Episode: [50000/47600], Median progress: 10.00, Median reward: 1.35, Win rate : 0.10, Epsilon: 0.01
# Episode: [50000/47700], Median progress: 11.00, Median reward: 1.50, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/47800], Median progress: 11.00, Median reward: 1.90, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/47900], Median progress: 10.50, Median reward: 1.90, Win rate : 0.13, Epsilon: 0.01
# Episode: [50000/48000], Median progress: 11.00, Median reward: 1.60, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/48100], Median progress: 11.00, Median reward: 1.65, Win rate : 0.12, Epsilon: 0.01
# Episode: [50000/48200], Median progress: 9.00, Median reward: 0.80, Win rate : 0.14, Epsilon: 0.01
# Episode: [50000/48300], Median progress: 11.00, Median reward: 1.40, Win rate : 0.08, Epsilon: 0.01
# Episode: [50000/48400], Median progress: 11.00, Median reward: 1.75, Win rate : 0.18, Epsilon: 0.01
# Valid n:1000, Median progress: 12.00, Median reward: 2.00, Win rate : 0.156
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.151
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.158
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.155
# Valid n:1000, Median progress: 12.00, Median reward: 2.00, Win rate : 0.174
# Valid n:1000, Median progress: 12.00, Median reward: 1.70, Win rate : 0.162
# Valid n:1000, Median progress: 12.00, Median reward: 1.70, Win rate : 0.156
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.143
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.151
# Valid n:1000, Median progress: 11.50, Median reward: 1.70, Win rate : 0.138
# Episode: [50000/48500], Median progress: 11.00, Median reward: 1.70, Win rate : 0.17, Epsilon: 0.01
# Episode: [50000/48600], Median progress: 11.00, Median reward: 1.90, Win rate : 0.16, Epsilon: 0.01
# Episode: [50000/48700], Median progress: 10.00, Median reward: 1.05, Win rate : 0.09, Epsilon: 0.01
# Episode: [50000/48800], Median progress: 9.00, Median reward: 0.90, Win rate : 0.19, Epsilon: 0.01
# Valid n:1000, Median progress: 12.00, Median reward: 1.90, Win rate : 0.18
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.159
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.164
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.154
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.165
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.166
# Valid n:1000, Median progress: 12.00, Median reward: 2.00, Win rate : 0.172
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.173
# Valid n:1000, Median progress: 12.00, Median reward: 2.00, Win rate : 0.176
# Valid n:1000, Median progress: 12.00, Median reward: 2.00, Win rate : 0.163
# Episode: [50000/48900], Median progress: 11.00, Median reward: 1.70, Win rate : 0.17, Epsilon: 0.01
# Episode: [50000/49000], Median progress: 10.50, Median reward: 1.50, Win rate : 0.11, Epsilon: 0.01
# Episode: [50000/49100], Median progress: 9.00, Median reward: 1.20, Win rate : 0.17, Epsilon: 0.01
# Episode: [50000/49200], Median progress: 10.50, Median reward: 1.40, Win rate : 0.12, Epsilon: 0.01
# Episode: [50000/49300], Median progress: 11.00, Median reward: 1.70, Win rate : 0.21, Epsilon: 0.01
# Valid n:1000, Median progress: 12.00, Median reward: 2.00, Win rate : 0.16
# Valid n:1000, Median progress: 12.00, Median reward: 2.00, Win rate : 0.186
# Valid n:1000, Median progress: 12.00, Median reward: 1.90, Win rate : 0.191
# Valid n:1000, Median progress: 12.00, Median reward: 1.95, Win rate : 0.173
# Valid n:1000, Median progress: 12.00, Median reward: 2.00, Win rate : 0.186
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.18
# Valid n:1000, Median progress: 12.00, Median reward: 2.00, Win rate : 0.2
# Valid n:1000, Median progress: 12.00, Median reward: 1.90, Win rate : 0.163
# Valid n:1000, Median progress: 12.00, Median reward: 1.90, Win rate : 0.189
# Valid n:1000, Median progress: 12.00, Median reward: 2.20, Win rate : 0.2
# Episode: [50000/49400], Median progress: 11.00, Median reward: 1.55, Win rate : 0.18, Epsilon: 0.01
# Episode: [50000/49500], Median progress: 12.00, Median reward: 2.00, Win rate : 0.22, Epsilon: 0.01
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.164
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.182
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.187
# Valid n:1000, Median progress: 11.00, Median reward: 1.90, Win rate : 0.168
# Valid n:1000, Median progress: 12.00, Median reward: 2.00, Win rate : 0.203
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.191
# Valid n:1000, Median progress: 12.00, Median reward: 1.90, Win rate : 0.199
# Valid n:1000, Median progress: 11.00, Median reward: 1.70, Win rate : 0.186
# Valid n:1000, Median progress: 11.00, Median reward: 1.60, Win rate : 0.168
# Valid n:1000, Median progress: 11.00, Median reward: 1.90, Win rate : 0.183
# Episode: [50000/49600], Median progress: 11.50, Median reward: 2.00, Win rate : 0.21, Epsilon: 0.01
# Episode: [50000/49700], Median progress: 11.50, Median reward: 1.95, Win rate : 0.14, Epsilon: 0.01
# Episode: [50000/49800], Median progress: 10.00, Median reward: 1.10, Win rate : 0.16, Epsilon: 0.01
# Episode: [50000/49900], Median progress: 11.00, Median reward: 1.35, Win rate : 0.10, Epsilon: 0.01
# Episode: [50000/50000], Median progress: 11.00, Median reward: 1.95, Win rate : 0.18, Epsilon: 0.01
# 4635.13
# 파일 '/content/drive/MyDrive/Minesweeper [RL]/models/basicModelWithoutBiasRuleDone_1'가 생성되었습니다.
# 모델이 저장되었습니다.

# %%
with open('/content/drive/MyDrive/Minesweeper [RL]/models/basicModelWithoutBiasRuleDone_1/50K.pkl', 'wb') as f:
    pickle.dump(train, f)

# %%
with open('/content/drive/MyDrive/Minesweeper [RL]/models/basicModelWithBiasWithoutRule/50K.pkl', 'rb') as f:
    t = pickle.load(f)

# %%
env.rewards
# Out:
# {'win': 1, 'lose': -1, 'progress': 0.3, 'guess': -0.3}

# %%
train.train()
# Out:
# Episode: [200/100], Median progress: 4.00, Median reward: -1.30, Win rate : 0.00, Epsilon: 0.20
# Episode: [200/200], Median progress: 5.00, Median reward: -1.30, Win rate : 0.00, Epsilon: 0.18

# %%
class Trainer:
    def __init__(self, env, agent):
        self.env = env
        self.agent = agent

        self.progress_list = []
        self.wins_list = []
        self.ep_rewards_list = []

        self.SIMPLE_VALID = 0
        self.tester_agent = DQNAgent(env=env, conv_units=CONV_UNITS)

        self.best_model_train = None
        self.best_model_valid = None

        self.baseline_train = 0
        self.baseline_valid = 0

        self.train()
        self.visualize_train()

    def train(self):
        global VALID_SAMPLE

        for episode in range(EPISODES):
            self.env.reset()

            n_clicks = 0
            done = False
            episode_reward = 0

            while not done:
                current_state = self.env.state

                action = self.agent.get_action(current_state)

                next_state, reward, done = self.env.step(action)

                episode_reward += reward

                self.agent.update_replay_memory((current_state, action, reward, next_state, done))

                if TRAIN_INTERVAL == TRAIN_INTERVALS[0]: # every timestep
                    self.agent.train(done)

                n_clicks += 1

            if TRAIN_INTERVAL == TRAIN_INTERVALS[1]: # every episodes
                self.agent.train(done)

            if TRAIN_RENDER:
                self.env.render(self.env.state)
                print(episode_reward)

            self.progress_list.append(n_clicks)
            self.ep_rewards_list.append(episode_reward)
            self.wins_list.append(reward == self.env.rewards['win'])

            if len(agent.replay_memory) < MEM_SIZE_MIN:
                continue

            if (episode+1) % PRINT_INTERVAL == 0:
                med_progress = np.median(self.progress_list[-PRINT_INTERVAL:])
                win_rate = np.sum(self.wins_list[-PRINT_INTERVAL:]) / PRINT_INTERVAL
                med_reward = np.median(self.ep_rewards_list[-PRINT_INTERVAL:])

                print(f"Episode: [{EPISODES}/{episode+1}], Median progress: {med_progress:.2f}, Median reward: {med_reward:.2f}, Win rate : {win_rate:.2f}, Epsilon: {agent.epsilon:.2f}")

                if win_rate > self.baseline_train:
                    self.baseline_train = win_rate
                    self.best_model_train = self.agent.model.state_dict()

                    self.SIMPLE_VALID = 10

            if self.SIMPLE_VALID > 0:
                valid_state = self.agent.model.state_dict()
                valid_win_rate = self.valid_model(self.env, self.tester_agent, episode, VALID_SAMPLE, valid_state)
                self.SIMPLE_VALID -= 1

                if win_rate > self.baseline_valid:
                    self.baseline_valid = valid_win_rate
                    self.best_model_valid = self.agent.model.state_dict()

    def valid_model(self, env, agent, episode, epoch, model_state):

        progress_list, wins_list, ep_rewards = [], [], []

        agent.epsilon = 0.0 # valid에서는 탐험을 꺼준다.

        agent.model.load_state_dict(model_state)
        agent.target_model.load_state_dict(model_state)

        for _ in range(epoch):
            env.reset()

            done = False
            n_clicks = 0
            episode_reward = 0

            while not done:
                current_state = env.state

                action = agent.get_action(current_state)
                _, reward, done = env.step(action)

                episode_reward += reward
                n_clicks += 1

            progress_list.append(n_clicks)
            ep_rewards.append(episode_reward)

            if reward == env.rewards['win']:
                wins_list.append(1)
            else:
                wins_list.append(0)

        print(f"Valid n:{epoch}, Median progress: {np.median(progress_list):.2f}, Median reward: {np.median(ep_rewards):.2f}, Win rate : {np.sum(wins_list)/len(wins_list)}")

        return np.sum(wins_list)/len(wins_list) # 승률을 반환한다.

    def visualize_train(self, progress=True, win_rates=True, rewards=True, losses=True):
        progresses = []
        win_rates = []
        rewards = []
        losses = []

        INTERVAL = 100

        for start in range(0, len(self.progress_list)-INTERVAL, INTERVAL):
            progresses.append(sum(self.progress_list[start:start+INTERVAL]) / INTERVAL)
            win_rates.append(sum(self.wins_list[start:start+INTERVAL]) / INTERVAL)
            rewards.append(sum(self.ep_rewards_list[start:start+INTERVAL]) / INTERVAL)
            losses.append(sum(self.agent.losses[start:start+INTERVAL]) / INTERVAL)

        interval = 50
        xticks = np.arange(0, len(self.progress_list), interval)

        if progress:
            if len(progresses) > 50:
                plt.xticks(xticks, [str(x) + 'K' for x in xticks // 10])
            plt.axhline(y=(sum(self.progress_list)/len(self.progress_list)), color='b', linestyle='-')
            plt.scatter(range(len(progresses)), progresses, marker='.',alpha=0.3,
                        color=['red' if x == max(progresses) else 'black' for x in progresses])
            plt.annotate(max(progresses), (progresses.index(max(progresses))+5, max(progresses)))
            plt.title(f"Median Progress per {INTERVAL} episodes")
            plt.show()

        if win_rates:
            if len(progresses) > 50:
                plt.xticks(xticks, [str(x) + 'K' for x in xticks // 10])
                plt.axhline(y=(sum(self.wins_list)/len(self.wins_list)), color='b', linestyle='-')
                plt.axhline(y=(sum(self.wins_list[-100:])/len(self.wins_list[-100:])), color='b', linestyle='--')
            plt.fill_between(range(len(win_rates)), min(win_rates), win_rates, alpha=0.7)
            plt.scatter(win_rates.index(max(win_rates)), max(win_rates), marker='.', color='r')
            plt.annotate(max(win_rates), (win_rates.index(max(win_rates))+5, max(win_rates)))
            plt.title(f"Median Win rate per {INTERVAL} episodes")
            plt.show()

        if rewards:
            if len(progresses) > 50:
                plt.xticks(xticks, [str(x) + 'K' for x in xticks // 10])
                plt.axhline(y=(sum(self.ep_rewards_list)/len(self.ep_rewards_list)), color='b', linestyle='-')
            plt.scatter(range(len(rewards)), rewards,
                        marker='.', alpha=0.3, color=['red' if x == max(rewards) else 'black' for x in rewards])
            plt.annotate(round(max(rewards),2), (rewards.index(max(rewards))+5, max(rewards)))
            plt.title(f"Median Episode Reward per {INTERVAL} episodes")
            plt.show()

        if losses:
            plt.xticks(xticks, [str(x) + 'K' for x in xticks // 10])
            plt.plot(losses)
            plt.title(f"Median Loss per {INTERVAL} episodes")
            plt.show()


    def save_model(self):

        def save_file(direction, fname, file):
           with open(os.path.join(direction, f'{fname}.pkl'), 'wb') as f:
                pickle.dump(file,f)

        def create_file(path, name):
            file_path = path + '/' + name
            # 파일이 이미 존재하는지 확인
            if not os.path.exists(file_path):
                os.makedirs(file_path)
                print(f"파일 '{file_path}'가 생성되었습니다.")
            else:
                print(f"파일 '{file_path}'는 이미 존재합니다.")

        save_point = {}
        save_point['n_mines'] = self.env.total_mines
        save_point['total_episodes'] = len(self.progress_list)
        save_point['final_model'] = self.agent.model.state_dict()
        save_point['best_model_train'] = self.best_model_train
        save_point['best_model_valid'] = self.best_model_valid

        f_path = '/content/drive/MyDrive/Minesweeper [RL]/models'
        name = 'basicModelWithBiasAndRule'

        create_file(f_path, name)
        save_file(f_path + '/' + name, f'{len(self.progress_list)}epi_max_train{self.baseline_train}_valid{self.baseline_valid}',save_point)
        print('모델이 저장되었습니다.')

EPISODES = 200
# Out:
# Episode: [200/100], Median progress: 5.00, Median reward: -1.30, Win rate : 0.00, Epsilon: 0.15
# Episode: [200/200], Median progress: 5.00, Median reward: -1.30, Win rate : 0.00, Epsilon: 0.13

# %%
len(train.progress_list)
# Out:
# 400

# %%
train.save_model()
# Out:
# 파일 '/content/drive/MyDrive/Minesweeper [RL]/models/basicModelWithBiasAndRule'는 이미 존재합니다.

# %% [markdown]
# # 03 Test
